# %%
#importing all the packages that I might need
import pandas as pd
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
sns.set(style="white")
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
pd.set_option('display.max_columns', 300)
from scipy.stats import norm

# %%
data_grad = pd.read_excel('graduation_rates_public_school.xlsx',sheet_name='All',header=8)
data_ell = pd.read_excel('graduation_rates_public_school.xlsx',sheet_name='ELL',header=8)
data_swd = pd.read_excel('graduation_rates_public_school.xlsx',sheet_name='SWD',header=8)
data_ethnicity = pd.read_excel('graduation_rates_public_school.xlsx',sheet_name='Ethnicity',header=8)
data_gender = pd.read_excel('graduation_rates_public_school.xlsx',sheet_name='Gender',header=8)
data_poverty = pd.read_excel('graduation_rates_public_school.xlsx',sheet_name='Poverty',header=8)

# %%
df_created = [data_ell,data_swd,data_ethnicity,data_gender,data_poverty]

# %%
data_grad.head()
# Out:
#       DBN                 School Name      Category  Cohort Year  \
# 0  01M292  Orchard Collegiate Academy  All Students         2014
# 1  01M292  Orchard Collegiate Academy  All Students         2013
# 2  01M292  Orchard Collegiate Academy  All Students         2012
# 3  01M292  Orchard Collegiate Academy  All Students         2011
# 4  01M292  Orchard Collegiate Academy  All Students         2010
#
#           Cohort   # #.1  % of cohort #.2 % of cohort.1 % of grads #.3  \
# 0  4 year August  29  28     0.965517  25       86.2069    89.2857   0
# 1  4 year August  36  25     0.694444  23       63.8889         92   0
# 2  4 year August  44  24     0.545455  20       45.4545    83.3333   1
# 3  4 year August  73  46     0.630137  41       56.1644    89.1304   0
# 4  4 year August  61  26     0.426230  26        42.623        100   1
#
#   % of cohort.2 % of grads.1 #.4 % of cohort.3 % of grads.2 #.5 % of cohort.4  \
# 0             0            0  25       86.2069      89.2857   3       10.3448
# 1             0            0  23       63.8889           92   2       5.55556
# 2       2.27273      4.16667  19       43.1818      79.1667   4       9.09091
# 3             0            0  41       56.1644      89.1304   5       6.84932
# 4       1.63934      3.84615  25       40.9836      96.1538   0             0
#
#   % of grads.3 #.6 % of cohort.5 #.7 % of cohort.6
# 0      10.7143   0             0   1       3.44828
# 1            8   3       8.33333   7       19.4444
# 2      16.6667  10       22.7273  10       22.7273
# 3      10.8696  18       24.6575   7       9.58904
# 4            0  18       29.5082  17       27.8689

# %%
data_grad.columns
# Out:
# Index(['DBN', 'School Name', 'Category', 'Cohort Year', 'Cohort', '#', '#.1',
#        '% of cohort', '#.2', '% of cohort.1', '% of grads', '#.3',
#        '% of cohort.2', '% of grads.1', '#.4', '% of cohort.3', '% of grads.2',
#        '#.5', '% of cohort.4', '% of grads.3', '#.6', '% of cohort.5', '#.7',
#        '% of cohort.6'],
#       dtype='object')

# %%
data_ell.head()
# Out:
#       DBN                 School Name Category  Cohort Year         Cohort  \
# 0  01M292  Orchard Collegiate Academy      ELL         2014  4 year August
# 1  01M292  Orchard Collegiate Academy      ELL         2013  4 year August
# 2  01M292  Orchard Collegiate Academy      ELL         2012  4 year August
# 3  01M292  Orchard Collegiate Academy      ELL         2011  4 year August
# 4  01M292  Orchard Collegiate Academy      ELL         2010  4 year August
#
#     # #.1 % of cohort #.2 % of cohort.1 % of grads #.3 % of cohort.2  \
# 0   1   s           s   s             s          s   s             s
# 1   2   s           s   s             s          s   s             s
# 2   6   s           s   s             s          s   s             s
# 3  14   3     21.4286   1       7.14286    33.3333   0             0
# 4  14   s           s   s             s          s   s             s
#
#   % of grads.1 #.4 % of cohort.3 % of grads.2 #.5 % of cohort.4 % of grads.3  \
# 0            s   s             s            s   s             s            s
# 1            s   s             s            s   s             s            s
# 2            s   s             s            s   s             s            s
# 3            0   1       7.14286      33.3333   2       14.2857      66.6667
# 4            s   s             s            s   s             s            s
#
#   #.6 % of cohort.5 #.7 % of cohort.6
# 0   s             s   s             s
# 1   s             s   s             s
# 2   s             s   s             s
# 3   8       57.1429   2       14.2857
# 4   s             s   s             s

# %%
data_swd.head()
# Out:
#       DBN                 School Name Category  Cohort Year         Cohort  \
# 0  01M292  Orchard Collegiate Academy  Not SWD         2014  4 year August
# 1  01M292  Orchard Collegiate Academy  Not SWD         2013  4 year August
# 2  01M292  Orchard Collegiate Academy  Not SWD         2012  4 year August
# 3  01M292  Orchard Collegiate Academy  Not SWD         2011  4 year August
# 4  01M292  Orchard Collegiate Academy  Not SWD         2010  4 year August
#
#     # #.1 % of cohort #.2 % of cohort.1 % of grads #.3 % of cohort.2  \
# 0  21  21         100  21           100        100   0             0
# 1  24  19     79.1667  19       79.1667        100   0             0
# 2  31  19     61.2903  18       58.0645    94.7368   1       3.22581
# 3  53  39     73.5849  38       71.6981    97.4359   0             0
# 4  47  25     53.1915  25       53.1915        100   1       2.12766
#
#   % of grads.1 #.4 % of cohort.3 % of grads.2 #.5 % of cohort.4 % of grads.3  \
# 0            0  21           100          100   0             0            0
# 1            0  19       79.1667          100   0             0            0
# 2      5.26316  17       54.8387      89.4737   1       3.22581      5.26316
# 3            0  38       71.6981      97.4359   1       1.88679       2.5641
# 4            4  24       51.0638           96   0             0            0
#
#   #.6 % of cohort.5 #.7 % of cohort.6
# 0   0             0   0             0
# 1   1       4.16667   4       16.6667
# 2   5        16.129   7       22.5806
# 3  10       18.8679   3       5.66038
# 4  10       21.2766  12       25.5319

# %%
data_ethnicity.tail()
# Out:
#           DBN                     School Name Category  Cohort Year  \
# 98095  32K564  Bushwick Community High School    White         2006
# 98096  32K564  Bushwick Community High School    White         2005
# 98097  32K564  Bushwick Community High School    White         2003
# 98098  32K564  Bushwick Community High School    White         2002
# 98099  32K564  Bushwick Community High School    White         2001
#
#             Cohort  # #.1 % of cohort #.2 % of cohort.1 % of grads #.3  \
# 98095  6 year June  5   2          40   0             0          0   0
# 98096  6 year June  2   s           s   s             s          s   s
# 98097  6 year June  1   s           s   s             s          s   s
# 98098  6 year June  2   s           s   s             s          s   s
# 98099  6 year June  2   s           s   s             s          s   s
#
#       % of cohort.2 % of grads.1 #.4 % of cohort.3 % of grads.2 #.5  \
# 98095             0            0   0             0            0   2
# 98096             s            s   s             s            s   s
# 98097             s            s   s             s            s   s
# 98098             s            s   s             s            s   s
# 98099             s            s   s             s            s   s
#
#       % of cohort.4 % of grads.3 #.6 % of cohort.5 #.7 % of cohort.6
# 98095            40          100   0             0   2            40
# 98096             s            s   s             s   s             s
# 98097             s            s   s             s   s             s
# 98098             s            s   s             s   s             s
# 98099             s            s   s             s   s             s

# %%
data_grad_2014 = data_grad[data_grad['Cohort Year'] == 2014]
data_grad_2014 = data_grad_2014[data_grad_2014['Cohort'] == '4 year August']

# %%
data_grad_2014.sample(10)
# Out:
#           DBN                                        School Name  \
# 4821   04M435       Manhattan Center for Science and Mathematics
# 23165  31R440                               New Dorp High School
# 20218  25Q460                               Flushing High School
# 20908  27Q302  Queens High School for Information, Research, ...
# 4743   04M372                      Esperanza Preparatory Academy
# 20559  26Q430                          Francis Lewis High School
# 1649   02M414                               N.Y.C. Museum School
# 165    01M458                          Forsyth Satellite Academy
# 16106  17K590            Medgar Evers College Preparatory School
# 15301  17K408                 Academy of Hospitality and Tourism
#
#            Category  Cohort Year         Cohort     #   #.1  % of cohort  #.2  \
# 4821   All Students         2014  4 year August   381   374     0.981627  364
# 23165  All Students         2014  4 year August   738   611     0.827913  531
# 20218  All Students         2014  4 year August   382   238     0.623037  214
# 20908  All Students         2014  4 year August    92    77     0.836957   70
# 4743   All Students         2014  4 year August    84    55     0.654762   50
# 20559  All Students         2014  4 year August  1180  1034     0.876271  992
# 1649   All Students         2014  4 year August   114   112     0.982456  110
# 165    All Students         2014  4 year August    73    27     0.369863   25
# 16106  All Students         2014  4 year August   207   202     0.975845  199
# 15301  All Students         2014  4 year August    50    44     0.880000   36
#
#       % of cohort.1 % of grads  #.3 % of cohort.2 % of grads.1  #.4  \
# 4821        95.5381    97.3262  258       67.7165       68.984  106
# 23165       71.9512    86.9067  179       24.2547      29.2962  352
# 20218       56.0209     89.916   21       5.49738      8.82353  193
# 20908        76.087    90.9091   14       15.2174      18.1818   56
# 4743        59.5238    90.9091    1       1.19048      1.81818   49
# 20559       84.0678    95.9381  606       51.3559      58.6073  386
# 1649        96.4912    98.2143   53       46.4912      47.3214   57
# 165         34.2466    92.5926    0             0            0   25
# 16106       96.1353    98.5149   45       21.7391      22.2772  154
# 15301            72    81.8182    0             0            0   36
#
#       % of cohort.3 % of grads.2 #.5 % of cohort.4 % of grads.3 #.6  \
# 4821        27.8215      28.3422  10       2.62467       2.6738   6
# 23165       47.6965      57.6105  80       10.8401      13.0933  78
# 20218       50.5236      81.0924  24       6.28272       10.084  72
# 20908       60.8696      72.7273   7        7.6087      9.09091   2
# 4743        58.3333      89.0909   5       5.95238      9.09091  19
# 20559       32.7119      37.3308  42       3.55932       4.0619  90
# 1649             50      50.8929   2       1.75439      1.78571   0
# 165         34.2466      92.5926   2       2.73973      7.40741  34
# 16106       74.3961      76.2376   3       1.44928      1.48515   4
# 15301            72      81.8182   8            16      18.1818   2
#
#       % of cohort.5 #.7 % of cohort.6
# 4821         1.5748   1      0.262467
# 23165       10.5691  36       4.87805
# 20218       18.8482  66       17.2775
# 20908       2.17391  13       14.1304
# 4743         22.619   6       7.14286
# 20559       7.62712  43       3.64407
# 1649              0   1      0.877193
# 165         46.5753  12       16.4384
# 16106       1.93237   0             0
# 15301             4   4             8

# %%
len(data_grad_2014)
# Out:
# 479

# %%
data_grad_2014 = data_grad_2014[['DBN','School Name','#','% of cohort']].reset_index()
data_grad_2014.head()
# Out:
#    index     DBN                          School Name   #  % of cohort
# 0      0  01M292           Orchard Collegiate Academy  29     0.965517
# 1     51  01M448  University Neighborhood High School  88     0.931818
# 2    108  01M450           East Side Community School  92     0.967391
# 3    165  01M458            Forsyth Satellite Academy  73     0.369863
# 4    205  01M509              Marta Valle High School  42     0.642857

# %%
data_grad_2014 = data_grad_2014[['DBN','School Name','#','% of cohort']]
data_grad_2014.head()
# Out:
#       DBN                          School Name   #  % of cohort
# 0  01M292           Orchard Collegiate Academy  29     0.965517
# 1  01M448  University Neighborhood High School  88     0.931818
# 2  01M450           East Side Community School  92     0.967391
# 3  01M458            Forsyth Satellite Academy  73     0.369863
# 4  01M509              Marta Valle High School  42     0.642857

# %%
data_ell.tail()
# Out:
#           DBN                     School Name Category  Cohort Year  \
# 57745  32K564  Bushwick Community High School  Not ELL         2005
# 57746  32K564  Bushwick Community High School  Not ELL         2004
# 57747  32K564  Bushwick Community High School  Not ELL         2003
# 57748  32K564  Bushwick Community High School  Not ELL         2002
# 57749  32K564  Bushwick Community High School  Not ELL         2001
#
#             Cohort    # #.1 % of cohort #.2 % of cohort.1 % of grads #.3  \
# 57745  6 year June  199  61     30.6533  24       12.0603    39.3443   0
# 57746  6 year June  178  47     26.4045  14       7.86517    29.7872   0
# 57747  6 year June  137  40     29.1971   5       3.64964       12.5   0
# 57748  6 year June  170  58     34.1176   1      0.588235    1.72414   0
# 57749  6 year June  148  59     39.8649   0             0          0   0
#
#       % of cohort.2 % of grads.1 #.4 % of cohort.3 % of grads.2 #.5  \
# 57745             0            0  24       12.0603      39.3443  37
# 57746             0            0  14       7.86517      29.7872  33
# 57747             0            0   5       3.64964         12.5  35
# 57748             0            0   1      0.588235      1.72414  57
# 57749             0            0   0             0            0  59
#
#       % of cohort.4 % of grads.3 #.6 % of cohort.5  #.7 % of cohort.6
# 57745        18.593      60.6557  26       13.0653  108       54.2714
# 57746       18.5393      70.2128  27       15.1685   97       54.4944
# 57747       25.5474         87.5  17       12.4088   79       57.6642
# 57748       33.5294      98.2759  24       14.1176   87       51.1765
# 57749       39.8649          100  18       12.1622   69       46.6216

# %%
#Create a function to clean the dataframes from the different excel sheets

def my_cleaner(dataframe):
#select year 2014 and cohort 4 year August
    dataframe = dataframe[dataframe['Cohort Year'] == 2014]
    dataframe = dataframe[dataframe['Cohort'] == '4 year August']
#keep only 3 columns from the dataframes  
    cols = [col for col in dataframe.columns if col in ['DBN','Category','#']]
    dataframe = dataframe[cols]
#transform the categories into columns
    dataframe = dataframe.groupby(['DBN','Category'])['#'].aggregate('first').unstack()
#due to columns removal - reset the index
    dataframe = dataframe.reset_index()
    return dataframe

# %%
data_ell.sample(5)
# Out:
#           DBN                                        School Name    Category  \
# 35389  15K497   The Boerum Hill School for International Studies         ELL
# 41849  19K615  Transit Tech Career and Technical Education Hi...         ELL
# 28702  12X245                                    NEW DAY ACADEMY     Not ELL
# 39295  18K415                 SAMUEL J TILDEN HS                  Former ELL
# 48993  25Q540                         Queens Academy High School  Former ELL
#
#        Cohort Year         Cohort  # #.1 % of cohort #.2 % of cohort.1  \
# 35389         2001    4 year June  8   1        12.5   0             0
# 41849         2010    6 year June  3   s           s   s             s
# 28702         2004    4 year June  5   0           0   0             0
# 39295         2005  4 year August  5   3          60   2            40
# 48993         2009    5 year June  5   2          40   2            40
#
#       % of grads #.3 % of cohort.2 % of grads.1 #.4 % of cohort.3  \
# 35389          0   0             0            0   0             0
# 41849          s   s             s            s   s             s
# 28702        NaN   0             0          NaN   0             0
# 39295    66.6667   0             0            0   2            40
# 48993        100   0             0            0   2            40
#
#       % of grads.2 #.5 % of cohort.4 % of grads.3 #.6 % of cohort.5 #.7  \
# 35389            0   1          12.5          100   7          87.5   0
# 41849            s   s             s            s   s             s   s
# 28702          NaN   0             0          NaN   4            80   1
# 39295      66.6667   1            20      33.3333   1            20   1
# 48993          100   0             0            0   0             0   3
#
#       % of cohort.6
# 35389             0
# 41849             s
# 28702            20
# 39295            20
# 48993            60

# %%
test = my_cleaner(data_ell)

# %%
test.sample(5)
# Out:
# Category     DBN   ELL  Former ELL  Not ELL
# 392       25Q241   4.0        24.0     73.0
# 80        03M402  12.0         5.0     68.0
# 401       25Q670  14.0        16.0    153.0
# 105       05M369   NaN         1.0     74.0
# 63        02M545   NaN        32.0     67.0

# %%
dataframes_to_merge=[my_cleaner(df) for df in df_created]
len(dataframes_to_merge)
# Out:
# 5

# %%
dataset = data_grad_2014
for x in range(5):
    dataset = dataset.merge(dataframes_to_merge[x],on = 'DBN',how = 'inner')

# %%
dataset.sample(5)
# Out:
#         DBN                                        School Name    #  \
# 6    01M539  New Explorations into Science, Technology and ...  131
# 272  14K561                    Williamsburg Preparatory School  157
# 443  29Q272  George Washington Carver High School for the S...  143
# 21   02M308                       Lower Manhattan Arts Academy   78
# 151  08X405                      Herbert H. Lehman High School  183
#
#      % of cohort   ELL  Former ELL  Not ELL  Not SWD   SWD  Asian  Black  \
# 6       0.938931   NaN         6.0    125.0    125.0   6.0   45.0   14.0
# 272     0.955414   2.0         4.0    151.0    138.0  19.0    7.0   27.0
# 443     0.748252   7.0         4.0    132.0    124.0  19.0   10.0  111.0
# 21      0.833333   NaN         2.0     76.0     51.0  27.0    7.0   21.0
# 151     0.573770  28.0        11.0    144.0    137.0  46.0   29.0   26.0
#
#      Hispanic  Multi-Racial  Native American  White  Female   Male  \
# 6        28.0           5.0              NaN   39.0    65.0   66.0
# 272     103.0           NaN              3.0   17.0    68.0   89.0
# 443      17.0           NaN              4.0    1.0    75.0   68.0
# 21       43.0           4.0              1.0    2.0    54.0   24.0
# 151     105.0           NaN              NaN   23.0    74.0  109.0
#
#      Econ Disadv  Not Econ Disadv
# 6           62.0             69.0
# 272        119.0             38.0
# 443        112.0             31.0
# 21          59.0             19.0
# 151        143.0             40.0

# %%
len(dataset)
# Out:
# 479

# %%
dataset = dataset.rename(columns={'#':'total_stud','% of cohort':'grad_rate'})

# %%
dataset.head()
# Out:
#       DBN                          School Name  total_stud  grad_rate  ELL  \
# 0  01M292           Orchard Collegiate Academy          29   0.965517  1.0
# 1  01M448  University Neighborhood High School          88   0.931818  1.0
# 2  01M450           East Side Community School          92   0.967391  NaN
# 3  01M458            Forsyth Satellite Academy          73   0.369863  6.0
# 4  01M509              Marta Valle High School          42   0.642857  2.0
#
#    Former ELL  Not ELL  Not SWD   SWD  Asian  Black  Hispanic  Multi-Racial  \
# 0         3.0     25.0     21.0   8.0    3.0    6.0      19.0           NaN
# 1         9.0     78.0     75.0  13.0   23.0   19.0      42.0           1.0
# 2         1.0     91.0     76.0  16.0    7.0   19.0      52.0           4.0
# 3         4.0     63.0     56.0  17.0    1.0   25.0      41.0           1.0
# 4         1.0     39.0     25.0  17.0    2.0   12.0      27.0           NaN
#
#    Native American  White  Female  Male  Econ Disadv  Not Econ Disadv
# 0              NaN    1.0     6.0  23.0         27.0              2.0
# 1              1.0    2.0    38.0  50.0         77.0             11.0
# 2              NaN   10.0    40.0  52.0         62.0             30.0
# 3              NaN    5.0    47.0  26.0         65.0              8.0
# 4              NaN    1.0    20.0  22.0         41.0              1.0

# %%
dataset.describe()
# Out:
#         total_stud   grad_rate         ELL  Former ELL      Not ELL  \
# count   479.000000  475.000000  388.000000  419.000000   479.000000
# mean    150.513570    0.741041   16.092784   11.579952   127.348643
# std     179.989735    0.229672   26.756663   18.817435   159.607015
# min       1.000000    0.000000    1.000000    1.000000     1.000000
# 25%      79.000000    0.677836    3.000000    3.000000    63.000000
# 50%      99.000000    0.795082    6.000000    5.000000    86.000000
# 75%     126.000000    0.901220   16.000000   11.000000   114.000000
# max    1322.000000    1.000000  184.000000  144.000000  1308.000000
#
#            Not SWD         SWD       Asian       Black    Hispanic  \
# count   478.000000  469.000000  401.000000  471.000000  475.000000
# mean    127.420502   23.857143   32.344140   41.050955   59.298947
# std     161.375680   24.016173   86.267846   38.718591   58.126908
# min       1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      64.000000   12.000000    2.000000   18.000000   22.500000
# 50%      80.500000   19.000000    6.000000   30.000000   48.000000
# 75%     107.750000   26.000000   23.000000   50.500000   71.500000
# max    1298.000000  170.000000  830.000000  276.000000  390.000000
#
#        Multi-Racial  Native American       White      Female        Male  \
# count    242.000000       230.000000  405.000000  476.000000  468.000000
# mean       4.049587         2.782609   24.701235   74.199580   78.583333
# std        5.621316         4.330823   67.081760   88.841409   97.258940
# min        1.000000         1.000000    1.000000    1.000000    2.000000
# 25%        1.000000         1.000000    2.000000   35.000000   38.000000
# 50%        2.000000         2.000000    4.000000   49.000000   50.000000
# 75%        4.000000         3.000000   18.000000   68.000000   69.000000
# max       39.000000        37.000000  808.000000  577.000000  800.000000
#
#        Econ Disadv  Not Econ Disadv
# count   479.000000       474.000000
# mean    112.469729        38.445148
# std     126.245206        66.273651
# min       1.000000         1.000000
# 25%      61.500000        10.000000
# 50%      80.000000        18.000000
# 75%     100.000000        34.750000
# max     861.000000       645.000000

# %%
dataset.dtypes
# Out:
# DBN                 object
# School Name         object
# total_stud           int64
# grad_rate          float64
# ELL                float64
# Former ELL         float64
# Not ELL            float64
# Not SWD            float64
# SWD                float64
# Asian              float64
# Black              float64
# Hispanic           float64
# Multi-Racial       float64
# Native American    float64
# White              float64
# Female             float64
# Male               float64
# Econ Disadv        float64
# Not Econ Disadv    float64
# dtype: object

# %%
dataset.boxplot(['grad_rate'])

# %%
#remove missing or incorrect value in grad_rate to keep only numeric
dataset=dataset[pd.to_numeric(dataset.grad_rate, errors='coerce').notnull()]

# %%
dataset.head()
# Out:
#       DBN                          School Name  total_stud  grad_rate  ELL  \
# 0  01M292           Orchard Collegiate Academy          29   0.965517  1.0
# 1  01M448  University Neighborhood High School          88   0.931818  1.0
# 2  01M450           East Side Community School          92   0.967391  NaN
# 3  01M458            Forsyth Satellite Academy          73   0.369863  6.0
# 4  01M509              Marta Valle High School          42   0.642857  2.0
#
#    Former ELL  Not ELL  Not SWD   SWD  Asian  Black  Hispanic  Multi-Racial  \
# 0         3.0     25.0     21.0   8.0    3.0    6.0      19.0           NaN
# 1         9.0     78.0     75.0  13.0   23.0   19.0      42.0           1.0
# 2         1.0     91.0     76.0  16.0    7.0   19.0      52.0           4.0
# 3         4.0     63.0     56.0  17.0    1.0   25.0      41.0           1.0
# 4         1.0     39.0     25.0  17.0    2.0   12.0      27.0           NaN
#
#    Native American  White  Female  Male  Econ Disadv  Not Econ Disadv
# 0              NaN    1.0     6.0  23.0         27.0              2.0
# 1              1.0    2.0    38.0  50.0         77.0             11.0
# 2              NaN   10.0    40.0  52.0         62.0             30.0
# 3              NaN    5.0    47.0  26.0         65.0              8.0
# 4              NaN    1.0    20.0  22.0         41.0              1.0

# %%
len(dataset)
# Out:
# 475

# %%
dataset.grad_rate.hist()

# %%
dataset.grad_rate.describe()
# Out:
# count    475.000000
# mean       0.741041
# std        0.229672
# min        0.000000
# 25%        0.677836
# 50%        0.795082
# 75%        0.901220
# max        1.000000
# Name: grad_rate, dtype: float64

# %%
columns_tobe_changed = list(dataset.columns)[4:]
columns_tobe_changed
# Out:
# ['ELL',
#  'Former ELL',
#  'Not ELL',
#  'Not SWD',
#  'SWD',
#  'Asian',
#  'Black',
#  'Hispanic',
#  'Multi-Racial',
#  'Native American',
#  'White',
#  'Female',
#  'Male',
#  'Econ Disadv',
#  'Not Econ Disadv']

# %%
new_cols = ['prob_'+x for x in columns_tobe_changed]
new_cols
# Out:
# ['prob_ELL',
#  'prob_Former ELL',
#  'prob_Not ELL',
#  'prob_Not SWD',
#  'prob_SWD',
#  'prob_Asian',
#  'prob_Black',
#  'prob_Hispanic',
#  'prob_Multi-Racial',
#  'prob_Native American',
#  'prob_White',
#  'prob_Female',
#  'prob_Male',
#  'prob_Econ Disadv',
#  'prob_Not Econ Disadv']

# %%
dataset[new_cols] = round(dataset[columns_tobe_changed].div(dataset.total_stud, axis=0),2)
dataset.head()
# Out:
#       DBN                          School Name  total_stud  grad_rate  ELL  \
# 0  01M292           Orchard Collegiate Academy          29   0.965517  1.0
# 1  01M448  University Neighborhood High School          88   0.931818  1.0
# 2  01M450           East Side Community School          92   0.967391  NaN
# 3  01M458            Forsyth Satellite Academy          73   0.369863  6.0
# 4  01M509              Marta Valle High School          42   0.642857  2.0
#
#    Former ELL  Not ELL  Not SWD   SWD  Asian  Black  Hispanic  Multi-Racial  \
# 0         3.0     25.0     21.0   8.0    3.0    6.0      19.0           NaN
# 1         9.0     78.0     75.0  13.0   23.0   19.0      42.0           1.0
# 2         1.0     91.0     76.0  16.0    7.0   19.0      52.0           4.0
# 3         4.0     63.0     56.0  17.0    1.0   25.0      41.0           1.0
# 4         1.0     39.0     25.0  17.0    2.0   12.0      27.0           NaN
#
#    Native American  White  Female  Male  Econ Disadv  Not Econ Disadv  \
# 0              NaN    1.0     6.0  23.0         27.0              2.0
# 1              1.0    2.0    38.0  50.0         77.0             11.0
# 2              NaN   10.0    40.0  52.0         62.0             30.0
# 3              NaN    5.0    47.0  26.0         65.0              8.0
# 4              NaN    1.0    20.0  22.0         41.0              1.0
#
#    prob_ELL  prob_Former ELL  prob_Not ELL  prob_Not SWD  prob_SWD  \
# 0      0.03             0.10          0.86          0.72      0.28
# 1      0.01             0.10          0.89          0.85      0.15
# 2       NaN             0.01          0.99          0.83      0.17
# 3      0.08             0.05          0.86          0.77      0.23
# 4      0.05             0.02          0.93          0.60      0.40
#
#    prob_Asian  prob_Black  prob_Hispanic  prob_Multi-Racial  \
# 0        0.10        0.21           0.66                NaN
# 1        0.26        0.22           0.48               0.01
# 2        0.08        0.21           0.57               0.04
# 3        0.01        0.34           0.56               0.01
# 4        0.05        0.29           0.64                NaN
#
#    prob_Native American  prob_White  prob_Female  prob_Male  prob_Econ Disadv  \
# 0                   NaN        0.03         0.21       0.79              0.93
# 1                  0.01        0.02         0.43       0.57              0.88
# 2                   NaN        0.11         0.43       0.57              0.67
# 3                   NaN        0.07         0.64       0.36              0.89
# 4                   NaN        0.02         0.48       0.52              0.98
#
#    prob_Not Econ Disadv
# 0                  0.07
# 1                  0.12
# 2                  0.33
# 3                  0.11
# 4                  0.02

# %%
dataset.describe()
# Out:
#         total_stud   grad_rate         ELL  Former ELL      Not ELL  \
# count   475.000000  475.000000  388.000000  419.000000   475.000000
# mean    151.766316    0.741041   16.092784   11.579952   128.406316
# std     180.225826    0.229672   26.756663   18.817435   159.859673
# min       5.000000    0.000000    1.000000    1.000000     1.000000
# 25%      79.000000    0.677836    3.000000    3.000000    64.000000
# 50%     100.000000    0.795082    6.000000    5.000000    86.000000
# 75%     126.500000    0.901220   16.000000   11.000000   114.000000
# max    1322.000000    1.000000  184.000000  144.000000  1308.000000
#
#            Not SWD         SWD       Asian       Black    Hispanic  \
# count   475.000000  468.000000  401.000000  467.000000  474.000000
# mean    128.212632   23.905983   32.344140   41.389722   59.421941
# std     161.575782   24.018545   86.267846   38.709800   58.126413
# min       2.000000    1.000000    1.000000    1.000000    1.000000
# 25%      65.000000   12.000000    2.000000   18.000000   23.000000
# 50%      81.000000   19.000000    6.000000   30.000000   48.000000
# 75%     108.000000   26.000000   23.000000   51.000000   71.750000
# max    1298.000000  170.000000  830.000000  276.000000  390.000000
#
#        Multi-Racial  Native American       White      Female        Male  \
# count    242.000000       230.000000  405.000000  472.000000  467.000000
# mean       4.049587         2.782609   24.701235   74.817797   78.747323
# std        5.621316         4.330823   67.081760   88.962054   97.298446
# min        1.000000         1.000000    1.000000    1.000000    3.000000
# 25%        1.000000         1.000000    2.000000   35.000000   38.000000
# 50%        2.000000         2.000000    4.000000   49.000000   50.000000
# 75%        4.000000         3.000000   18.000000   68.500000   69.000000
# max       39.000000        37.000000  808.000000  577.000000  800.000000
#
#        Econ Disadv  Not Econ Disadv    prob_ELL  prob_Former ELL  \
# count   475.000000       474.000000  388.000000       419.000000
# mean    113.402105        38.445148    0.119897         0.074916
# std     126.364604        66.273651    0.158682         0.085757
# min       3.000000         1.000000    0.000000         0.000000
# 25%      62.000000        10.000000    0.030000         0.030000
# 50%      80.000000        18.000000    0.060000         0.050000
# 75%     100.000000        34.750000    0.130000         0.090000
# max     861.000000       645.000000    0.850000         0.600000
#
#        prob_Not ELL  prob_Not SWD    prob_SWD  prob_Asian  prob_Black  \
# count    475.000000    475.000000  468.000000  401.000000  467.000000
# mean       0.836253      0.819853    0.182842    0.119352    0.350642
# std        0.208849      0.091447    0.089411    0.146856    0.245137
# min        0.010000      0.400000    0.000000    0.010000    0.000000
# 25%        0.810000      0.760000    0.130000    0.020000    0.170000
# 50%        0.900000      0.820000    0.180000    0.060000    0.280000
# 75%        0.960000      0.880000    0.240000    0.150000    0.470000
# max        1.000000      1.000000    0.600000    0.880000    0.960000
#
#        prob_Hispanic  prob_Multi-Racial  prob_Native American  prob_White  \
# count     474.000000         242.000000            230.000000  405.000000
# mean        0.448165           0.025083              0.018565    0.100148
# std         0.245225           0.022282              0.022932    0.134578
# min         0.030000           0.000000              0.000000    0.000000
# 25%         0.230000           0.010000              0.010000    0.020000
# 50%         0.460000           0.020000              0.010000    0.040000
# 75%         0.640000           0.030000              0.020000    0.120000
# max         1.000000           0.200000              0.280000    0.790000
#
#        prob_Female   prob_Male  prob_Econ Disadv  prob_Not Econ Disadv
# count   472.000000  467.000000        475.000000            474.000000
# mean      0.498602    0.513169          0.785916              0.214536
# std       0.140571    0.130824          0.137550              0.137342
# min       0.060000    0.070000          0.210000              0.010000
# 25%       0.430000    0.440000          0.740000              0.120000
# 50%       0.490000    0.510000          0.810000              0.190000
# 75%       0.570000    0.580000          0.880000              0.260000
# max       1.000000    1.000000          1.000000              0.790000

# %%
sns.scatterplot(dataset['prob_Female'], dataset.grad_rate)

# %%
new_cols
# Out:
# ['prob_ELL',
#  'prob_Former ELL',
#  'prob_Not ELL',
#  'prob_Not SWD',
#  'prob_SWD',
#  'prob_Asian',
#  'prob_Black',
#  'prob_Hispanic',
#  'prob_Multi-Racial',
#  'prob_Native American',
#  'prob_White',
#  'prob_Female',
#  'prob_Male',
#  'prob_Econ Disadv',
#  'prob_Not Econ Disadv']

# %%
for col in new_cols:
    sns.jointplot(x=col, y='grad_rate', data=dataset, kind="reg",height=5)

# %%
n = 4
row_groups= [new_cols[i:i+n] for i in range(0, len(new_cols), n) ]
for i in row_groups:
    pp = sns.pairplot(data=dataset, y_vars=['grad_rate'],x_vars=i, kind="reg", height=3)

# %%
dataset.to_csv("dataset.csv")

# %%
# two rows have grad rate of 0%.  Removing them
dataset[dataset['grad_rate'] == 0]
# Out:
#         DBN                                 School Name  total_stud  \
# 130  07X520  FOREIGN LANGUAGE ACADEMY OF GLOBAL STUDIES           5
# 167  09X276                        LEADERSHIP INSTITUTE           5
#
#      grad_rate  ELL  Former ELL  Not ELL  Not SWD  SWD  Asian  Black  \
# 130        0.0  3.0         NaN      2.0      5.0  NaN    NaN    1.0
# 167        0.0  2.0         NaN      3.0      2.0  3.0    NaN    1.0
#
#      Hispanic  Multi-Racial  Native American  White  Female  Male  \
# 130       4.0           NaN              NaN    NaN     1.0   4.0
# 167       4.0           NaN              NaN    NaN     2.0   3.0
#
#      Econ Disadv  Not Econ Disadv  prob_ELL  prob_Former ELL  prob_Not ELL  \
# 130          3.0              2.0       0.6              NaN           0.4
# 167          3.0              2.0       0.4              NaN           0.6
#
#      prob_Not SWD  prob_SWD  prob_Asian  prob_Black  prob_Hispanic  \
# 130           1.0       NaN         NaN         0.2            0.8
# 167           0.4       0.6         NaN         0.2            0.8
#
#      prob_Multi-Racial  prob_Native American  prob_White  prob_Female  \
# 130                NaN                   NaN         NaN          0.2
# 167                NaN                   NaN         NaN          0.4
#
#      prob_Male  prob_Econ Disadv  prob_Not Econ Disadv
# 130        0.8               0.6                   0.4
# 167        0.6               0.6                   0.4

# %%
d = dataset[dataset['grad_rate'] > 0]
len(dataset)-len(d)
# Out:
# 2

# %%
d.grad_rate.describe()
# Out:
# count    473.000000
# mean       0.744174
# std        0.225025
# min        0.041667
# 25%        0.684783
# 50%        0.795620
# 75%        0.902439
# max        1.000000
# Name: grad_rate, dtype: float64

# %%
plt.matshow(d.corr())
plt.xticks(range(len(d.columns)), d.columns)
plt.yticks(range(len(d.columns)), d.columns)
plt.colorbar()
plt.show()

# %%
d.columns
# Out:
# Index(['DBN', 'School Name', 'total_stud', 'grad_rate', 'ELL', 'Former ELL',
#        'Not ELL', 'Not SWD', 'SWD', 'Asian', 'Black', 'Hispanic',
#        'Multi-Racial', 'Native American', 'White', 'Female', 'Male',
#        'Econ Disadv', 'Not Econ Disadv', 'prob_ELL', 'prob_Former ELL',
#        'prob_Not ELL', 'prob_Not SWD', 'prob_SWD', 'prob_Asian', 'prob_Black',
#        'prob_Hispanic', 'prob_Multi-Racial', 'prob_Native American',
#        'prob_White', 'prob_Female', 'prob_Male', 'prob_Econ Disadv',
#        'prob_Not Econ Disadv'],
#       dtype='object')

# %%
filtered_cols_d = [
'total_stud', 'prob_Former ELL',
       'prob_Not ELL', 'prob_Not SWD', 'prob_Asian', 'prob_Black',
       'prob_Hispanic',
       'prob_White', 'prob_Female', 'prob_Male'
]

# %%
#Replace missing value with 0
d = d.fillna(0)

features_model = sm.OLS(endog=d['grad_rate'], exog=sm.add_constant(d[filtered_cols_d]) ).fit()
features_model.summary()
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              grad_rate   R-squared:                       0.286
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     18.54
# Date:                Fri, 23 Aug 2019   Prob (F-statistic):           1.22e-28
# Time:                        12:54:36   Log-Likelihood:                 114.65
# No. Observations:                 473   AIC:                            -207.3
# Df Residuals:                     462   BIC:                            -161.5
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -4.6419     19.258     -0.241      0.810     -42.486      33.202
# total_stud      -3.693e-05   5.76e-05     -0.641      0.522      -0.000    7.63e-05
# prob_Former ELL     1.1508      0.182      6.341      0.000       0.794       1.508
# prob_Not ELL        0.6917      0.079      8.799      0.000       0.537       0.846
# prob_Not SWD        0.7459      0.127      5.895      0.000       0.497       0.995
# prob_Asian          0.4426      0.362      1.221      0.223      -0.269       1.155
# prob_Black          0.2254      0.343      0.657      0.511      -0.448       0.899
# prob_Hispanic       0.3062      0.342      0.894      0.372      -0.367       0.979
# prob_White          0.4790      0.348      1.378      0.169      -0.204       1.162
# prob_Female         3.8280     19.253      0.199      0.842     -34.007      41.663
# prob_Male           3.8199     19.255      0.198      0.843     -34.018      41.658
# ==============================================================================
# Omnibus:                      164.892   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              434.680
# Skew:                          -1.744   Prob(JB):                     4.08e-95
# Kurtosis:                       6.144   Cond. No.                     8.91e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.91e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# for col in filtered_cols:
#     sns.jointplot(x=col, y='grad_log', data=dataset, kind="reg",height=5)

# %%
def checkresiduals(df, target, sm_model):
    # checking for our model - Homoscedasticity,  Independence of residuals
    pred_val = sm_model.fittedvalues.copy()
    true_val = df[target].values.copy()
    residual = true_val - pred_val

    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
#     fig, ax = plt.subplots(figsize=(8, 6))
    ax1.hist(residual, density=True, bins=30)
    ax2.scatter(df[target],residual)
    ax2.set_title('Residual Scatterplot')
    plt.show()

# %%
# same as above, except removed the two zeros
checkresiduals(d, 'grad_rate', features_model)

# %%
d['grad_log'] = np.log(d['grad_rate'])
checkresiduals(d, 'grad_log', features_model)

# %%
d['grad_recipr'] = 1/d['grad_rate']
checkresiduals(d, 'grad_recipr', features_model)

# %%
achievement = pd.read_csv('Student_Achievement.csv', skiprows = 1)
achievement = achievement.rename(columns={'Metric Value - Graduation Rate, 4 year':'gradrate'})

# %%
# merge d (which is just the original dataset minus the 2 zero grad_rates)
# with student achievement tab in HS Quality Reports file
newset = d.merge(achievement,on = 'DBN',how = 'inner')

# %%
newset = newset.rename(columns={'Student Achievement - Section Score':'SA_score'})

# %%
# attempted running model using Student Achievement as target variable instead of grad_rate- too many interactions
newset.SA_score.hist()

# %%
newset = newset.drop(['Former ELL', 'Not SWD', 'Asian', 'Hispanic', 'Native American', 'Female'], axis=1)

# %%
newset = newset.drop(['prob_ELL', 'prob_SWD', 'prob_Multi-Racial', 'grad_log'], axis=1)

# %%
merged_set = newset[['DBN',
'School Name_x',
'total_stud',
'grad_rate',
'prob_Former ELL',
'prob_Not ELL',
'prob_Not SWD',
'prob_Asian',
'prob_Black',
'prob_Hispanic',
'prob_Native American',
'prob_White',
'prob_Female',
'prob_Male',
'prob_Econ Disadv',
'prob_Not Econ Disadv',
'SA_score',
'Metric Score - Percentage Earning 10+ Credits in First Year',
'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in First Year',
'Metric Score - Percentage Earning 10+ Credits in Second Year',
'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Second Year',
'Metric Score - Percentage Earning 10+ Credits in Third Year',
'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Third Year',
'Metric Score - Average Completion Rate for Remaining Regents',
'Metric Score - Weighted Regents Pass Rate, English',
'Metric Score - Weighted Regents Pass Rate, Math',
'Metric Score - Weighted Regents Pass Rate, Science'
,'Metric Score - Weighted Regents Pass Rate, Global History'
,'Metric Score - Weighted Regents Pass Rate, US History'
,'Metric Score - Graduation Rate, 4 year'
,'Metric Score - Graduation Rate, 6 year'
,'Metric Score - Weighted Diploma Rate, 4 year'
,'Metric Score - Weighted Diploma Rate, 6 year'
,'Metric Score - College and Career Preparatory Course Index'
,'Metric Score - Four-year College Readiness Index'
,'Metric Score - College Readiness Rate including persistence'
,'Metric Score - Postsecondary Enrollment Rate, 6 months After High School'
,'Metric Score - Postsecondary Enrollment Rate, 18 months After High School'
,'Metric Value - Non-Dropout Rate, 4 year'
,'Metric Value - Non-Dropout Rate, 6 year'
]]

# %%
print(d.shape, newset.shape, merged_set.shape)
# Out:
# (473, 36) (420, 135) (420, 40)

# %%
merged_set.columns
# Out:
# Index(['DBN', 'School Name_x', 'total_stud', 'grad_rate', 'prob_Former ELL',
#        'prob_Not ELL', 'prob_Not SWD', 'prob_Asian', 'prob_Black',
#        'prob_Hispanic', 'prob_Native American', 'prob_White', 'prob_Female',
#        'prob_Male', 'prob_Econ Disadv', 'prob_Not Econ Disadv', 'SA_score',
#        'Metric Score - Percentage Earning 10+ Credits in First Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in First Year',
#        'Metric Score - Percentage Earning 10+ Credits in Second Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Second Year',
#        'Metric Score - Percentage Earning 10+ Credits in Third Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Third Year',
#        'Metric Score - Average Completion Rate for Remaining Regents',
#        'Metric Score - Weighted Regents Pass Rate, English',
#        'Metric Score - Weighted Regents Pass Rate, Math',
#        'Metric Score - Weighted Regents Pass Rate, Science',
#        'Metric Score - Weighted Regents Pass Rate, Global History',
#        'Metric Score - Weighted Regents Pass Rate, US History',
#        'Metric Score - Graduation Rate, 4 year',
#        'Metric Score - Graduation Rate, 6 year',
#        'Metric Score - Weighted Diploma Rate, 4 year',
#        'Metric Score - Weighted Diploma Rate, 6 year',
#        'Metric Score - College and Career Preparatory Course Index',
#        'Metric Score - Four-year College Readiness Index',
#        'Metric Score - College Readiness Rate including persistence',
#        'Metric Score - Postsecondary Enrollment Rate, 6 months After High School',
#        'Metric Score - Postsecondary Enrollment Rate, 18 months After High School',
#        'Metric Value - Non-Dropout Rate, 4 year',
#        'Metric Value - Non-Dropout Rate, 6 year'],
#       dtype='object')

# %%
merged_set.isna().sum()
# Out:
# DBN                                                                                   0
# School Name_x                                                                         0
# total_stud                                                                            0
# grad_rate                                                                             0
# prob_Former ELL                                                                       0
# prob_Not ELL                                                                          0
# prob_Not SWD                                                                          0
# prob_Asian                                                                            0
# prob_Black                                                                            0
# prob_Hispanic                                                                         0
# prob_Native American                                                                  0
# prob_White                                                                            0
# prob_Female                                                                           0
# prob_Male                                                                             0
# prob_Econ Disadv                                                                      0
# prob_Not Econ Disadv                                                                  0
# SA_score                                                                             42
# Metric Score - Percentage Earning 10+ Credits in First Year                           9
# Metric Score - Lowest Third School, Percentage Earning 10+ Credits in First Year     12
# Metric Score - Percentage Earning 10+ Credits in Second Year                          9
# Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Second Year    12
# Metric Score - Percentage Earning 10+ Credits in Third Year                          28
# Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Third Year     30
# Metric Score - Average Completion Rate for Remaining Regents                         45
# Metric Score - Weighted Regents Pass Rate, English                                   21
# Metric Score - Weighted Regents Pass Rate, Math                                      34
# Metric Score - Weighted Regents Pass Rate, Science                                   45
# Metric Score - Weighted Regents Pass Rate, Global History                            46
# Metric Score - Weighted Regents Pass Rate, US History                                58
# Metric Score - Graduation Rate, 4 year                                               42
# Metric Score - Graduation Rate, 6 year                                               73
# Metric Score - Weighted Diploma Rate, 4 year                                         42
# Metric Score - Weighted Diploma Rate, 6 year                                         73
# Metric Score - College and Career Preparatory Course Index                           42
# Metric Score - Four-year College Readiness Index                                     42
# Metric Score - College Readiness Rate including persistence                          73
# Metric Score - Postsecondary Enrollment Rate, 6 months After High School             56
# Metric Score - Postsecondary Enrollment Rate, 18 months After High School            73
# Metric Value - Non-Dropout Rate, 4 year                                              42
# Metric Value - Non-Dropout Rate, 6 year                                              73
# dtype: int64

# %%
#Checking missing data
sns.heatmap(merged_set.isnull(), cbar=False)

# %%
#Replace missing value with 0
merged_set = merged_set.fillna(0)

# %%
filtered_cols_m = [
'prob_Former ELL',
'prob_Not ELL',
'prob_Not SWD',
'prob_Asian',
'prob_Black',
'prob_Hispanic',
'prob_White',
'Metric Score - Weighted Regents Pass Rate, Science'
,'Metric Score - Weighted Regents Pass Rate, US History'
,'Metric Score - Four-year College Readiness Index'
]

# %%
merged_set[filtered_cols_m].dtypes
# Out:
# prob_Former ELL                                          float64
# prob_Not ELL                                             float64
# prob_Not SWD                                             float64
# prob_Asian                                               float64
# prob_Black                                               float64
# prob_Hispanic                                            float64
# prob_White                                               float64
# Metric Score - Weighted Regents Pass Rate, Science       float64
# Metric Score - Weighted Regents Pass Rate, US History    float64
# Metric Score - Four-year College Readiness Index         float64
# dtype: object

# %%
features_model = sm.OLS(endog=merged_set['grad_rate'], exog=sm.add_constant(merged_set[filtered_cols_m]) ).fit()

features_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              grad_rate   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     42.27
# Date:                Fri, 23 Aug 2019   Prob (F-statistic):           4.81e-57
# Time:                        12:55:45   Log-Likelihood:                 378.78
# No. Observations:                 420   AIC:                            -735.6
# Df Residuals:                     409   BIC:                            -691.1
# Df Model:                          10
# Covariance Type:            nonrobust
# =========================================================================================================================
#                                                             coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# const                                                    -0.4929      0.232     -2.122      0.034      -0.949      -0.036
# prob_Former ELL                                           0.7459      0.106      7.015      0.000       0.537       0.955
# prob_Not ELL                                              0.6080      0.049     12.523      0.000       0.513       0.703
# prob_Not SWD                                              0.7286      0.073      9.914      0.000       0.584       0.873
# prob_Asian                                                0.0891      0.220      0.405      0.686      -0.344       0.522
# prob_Black                                                0.0518      0.211      0.245      0.806      -0.363       0.467
# prob_Hispanic                                             0.1228      0.210      0.584      0.560      -0.291       0.536
# prob_White                                                0.2141      0.212      1.011      0.313      -0.202       0.630
# Metric Score - Weighted Regents Pass Rate, Science        0.0033      0.006      0.570      0.569      -0.008       0.015
# Metric Score - Weighted Regents Pass Rate, US History     0.0004      0.005      0.074      0.941      -0.010       0.010
# Metric Score - Four-year College Readiness Index          0.0076      0.004      2.032      0.043       0.000       0.015
# ==============================================================================
# Omnibus:                       78.425   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              192.702
# Skew:                          -0.929   Prob(JB):                     1.43e-42
# Kurtosis:                       5.750   Cond. No.                         561.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
checkresiduals(merged_set, 'grad_rate', features_model)

# %%
def CorrMtx(df, dropDuplicates = True):

    # Your dataset is already a correlation matrix.
    # If you have a dateset where you need to include the calculation
    # of a correlation matrix, just uncomment the line below:
    # df = df.corr()

    # Exclude duplicate correlations by masking uper right values
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True

    # Set background color / chart style
    sns.set_style(style = 'white')

    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))

    # Add diverging colormap from red to blue
    cmap = sns.diverging_palette(250, 10, as_cmap=True)

    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        sns.heatmap(df, mask=mask, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)
        plt.xticks(rotation = 90)
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)
        plt.xticks(rotation = 90)

# %%
CorrMtx(merged_set[filtered_cols_m].corr(), dropDuplicates = True)

# %%
# add Student Quality Review table
sqr = pd.read_csv('SQR_Summary2.csv', skiprows = 1)

# %%
# filter columns
sqr = sqr[['DBN', 'Enrollment',
'Rigorous Instruction - Percent Positive',
'Collaborative Teachers - Percent Positive',
'Supportive Environment - Percent Positive',
'Effective School Leadership - Percent Positive',
'Strong Family-Community Ties - Percent Positive',
'Trust - Percent Positive',
'Average Grade 8 English Proficiency',
'Average Grade 8 Math Proficiency', 'Percent English Language Learners',
'Percent Students with Disabilities', 'Percent Self-Contained',
'Economic Need Index', 'Percent in Temp Housing - 4yr',
'Percent HRA Eligible', 'Percent Asian', 'Percent Black',
'Percent Hispanic', 'Percent White',
'Years of principal experience at this school',
'Percent of teachers with 3 or more years of experience',
'Student Attendance Rate', 'Percent of Students Chronically Absent',
'Teacher Attendance Rate']]

# %%
sqr.columns
# Out:
# Index(['DBN', 'Enrollment', 'Rigorous Instruction - Percent Positive',
#        'Collaborative Teachers - Percent Positive',
#        'Supportive Environment - Percent Positive',
#        'Effective School Leadership - Percent Positive',
#        'Strong Family-Community Ties - Percent Positive',
#        'Trust - Percent Positive', 'Average Grade 8 English Proficiency',
#        'Average Grade 8 Math Proficiency', 'Percent English Language Learners',
#        'Percent Students with Disabilities', 'Percent Self-Contained',
#        'Economic Need Index', 'Percent in Temp Housing - 4yr',
#        'Percent HRA Eligible', 'Percent Asian', 'Percent Black',
#        'Percent Hispanic', 'Percent White',
#        'Years of principal experience at this school',
#        'Percent of teachers with 3 or more years of experience',
#        'Student Attendance Rate', 'Percent of Students Chronically Absent',
#        'Teacher Attendance Rate'],
#       dtype='object')

# %%
print(merged_set.shape, sqr.shape)
# Out:
# (420, 40) (491, 25)

# %%
# merge merged_set with sqr (third table)
bigset = merged_set.merge(sqr,on = 'DBN',how = 'inner')

# %%
bigset.shape
# Out:
# (420, 64)

# %%
#Replace missing value with 0
bigset = bigset.fillna(0)

# %%
CorrMtx(bigset.corr(), dropDuplicates = True)

# %%
bigset.columns
# Out:
# Index(['DBN', 'School Name_x', 'total_stud', 'grad_rate', 'prob_Former ELL',
#        'prob_Not ELL', 'prob_Not SWD', 'prob_Asian', 'prob_Black',
#        'prob_Hispanic', 'prob_Native American', 'prob_White', 'prob_Female',
#        'prob_Male', 'prob_Econ Disadv', 'prob_Not Econ Disadv', 'SA_score',
#        'Metric Score - Percentage Earning 10+ Credits in First Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in First Year',
#        'Metric Score - Percentage Earning 10+ Credits in Second Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Second Year',
#        'Metric Score - Percentage Earning 10+ Credits in Third Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Third Year',
#        'Metric Score - Average Completion Rate for Remaining Regents',
#        'Metric Score - Weighted Regents Pass Rate, English',
#        'Metric Score - Weighted Regents Pass Rate, Math',
#        'Metric Score - Weighted Regents Pass Rate, Science',
#        'Metric Score - Weighted Regents Pass Rate, Global History',
#        'Metric Score - Weighted Regents Pass Rate, US History',
#        'Metric Score - Graduation Rate, 4 year',
#        'Metric Score - Graduation Rate, 6 year',
#        'Metric Score - Weighted Diploma Rate, 4 year',
#        'Metric Score - Weighted Diploma Rate, 6 year',
#        'Metric Score - College and Career Preparatory Course Index',
#        'Metric Score - Four-year College Readiness Index',
#        'Metric Score - College Readiness Rate including persistence',
#        'Metric Score - Postsecondary Enrollment Rate, 6 months After High School',
#        'Metric Score - Postsecondary Enrollment Rate, 18 months After High School',
#        'Metric Value - Non-Dropout Rate, 4 year',
#        'Metric Value - Non-Dropout Rate, 6 year', 'Enrollment',
#        'Rigorous Instruction - Percent Positive',
#        'Collaborative Teachers - Percent Positive',
#        'Supportive Environment - Percent Positive',
#        'Effective School Leadership - Percent Positive',
#        'Strong Family-Community Ties - Percent Positive',
#        'Trust - Percent Positive', 'Average Grade 8 English Proficiency',
#        'Average Grade 8 Math Proficiency', 'Percent English Language Learners',
#        'Percent Students with Disabilities', 'Percent Self-Contained',
#        'Economic Need Index', 'Percent in Temp Housing - 4yr',
#        'Percent HRA Eligible', 'Percent Asian', 'Percent Black',
#        'Percent Hispanic', 'Percent White',
#        'Years of principal experience at this school',
#        'Percent of teachers with 3 or more years of experience',
#        'Student Attendance Rate', 'Percent of Students Chronically Absent',
#        'Teacher Attendance Rate'],
#       dtype='object')

# %%
bigset.describe()
# Out:
#         total_stud   grad_rate  prob_Former ELL  prob_Not ELL  prob_Not SWD  \
# count   420.000000  420.000000       420.000000    420.000000    420.000000
# mean    159.588095    0.804877         0.070357      0.836786      0.823476
# std     189.362627    0.140192         0.087392      0.206393      0.085390
# min       5.000000    0.066667         0.000000      0.010000      0.490000
# 25%      81.000000    0.724638         0.020000      0.800000      0.770000
# 50%     101.000000    0.813642         0.050000      0.900000      0.830000
# 75%     131.000000    0.910830         0.090000      0.960000      0.880000
# max    1322.000000    1.000000         0.600000      1.000000      1.000000
#
#        prob_Asian  prob_Black  prob_Hispanic  prob_Native American  \
# count  420.000000  420.000000     420.000000            420.000000
# mean     0.107476    0.334714       0.445524              0.008143
# std      0.144235    0.246639       0.247852              0.012847
# min      0.000000    0.000000       0.000000              0.000000
# 25%      0.020000    0.147500       0.220000              0.000000
# 50%      0.050000    0.270000       0.460000              0.000000
# 75%      0.140000    0.460000       0.640000              0.010000
# max      0.880000    0.960000       1.000000              0.080000
#
#        prob_White  prob_Female   prob_Male  prob_Econ Disadv  \
# count  420.000000   420.000000  420.000000        420.000000
# mean     0.089952     0.494667    0.505310          0.780000
# std      0.134647     0.151379    0.151368          0.140449
# min      0.000000     0.000000    0.000000          0.210000
# 25%      0.010000     0.420000    0.430000          0.730000
# 50%      0.030000     0.490000    0.510000          0.800000
# 75%      0.110000     0.570000    0.580000          0.870000
# max      0.790000     1.000000    1.000000          1.000000
#
#        prob_Not Econ Disadv    SA_score  \
# count            420.000000  420.000000
# mean               0.220000    3.096119
# std                0.140449    1.210269
# min                0.000000    0.000000
# 25%                0.130000    2.750000
# 50%                0.200000    3.315000
# 75%                0.270000    3.862500
# max                0.790000    4.990000
#
#        Metric Score - Percentage Earning 10+ Credits in First Year  \
# count                                         420.000000
# mean                                            3.343595
# std                                             1.166407
# min                                             0.000000
# 25%                                             2.645000
# 50%                                             3.515000
# 75%                                             4.272500
# max                                             4.990000
#
#        Metric Score - Lowest Third School, Percentage Earning 10+ Credits in First Year  \
# count                                         420.000000
# mean                                            3.267048
# std                                             1.207703
# min                                             0.000000
# 25%                                             2.380000
# 50%                                             3.440000
# 75%                                             4.232500
# max                                             4.990000
#
#        Metric Score - Percentage Earning 10+ Credits in Second Year  \
# count                                         420.000000
# mean                                            3.312833
# std                                             1.119083
# min                                             0.000000
# 25%                                             2.542500
# 50%                                             3.480000
# 75%                                             4.220000
# max                                             4.990000
#
#        Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Second Year  \
# count                                         420.000000
# mean                                            3.315524
# std                                             1.159341
# min                                             0.000000
# 25%                                             2.507500
# 50%                                             3.410000
# 75%                                             4.202500
# max                                             4.990000
#
#        Metric Score - Percentage Earning 10+ Credits in Third Year  \
# count                                         420.000000
# mean                                            3.116238
# std                                             1.295109
# min                                             0.000000
# 25%                                             2.317500
# 50%                                             3.325000
# 75%                                             4.150000
# max                                             4.990000
#
#        Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Third Year  \
# count                                         420.000000
# mean                                            3.070738
# std                                             1.337032
# min                                             0.000000
# 25%                                             2.207500
# 50%                                             3.275000
# 75%                                             4.142500
# max                                             4.990000
#
#        Metric Score - Average Completion Rate for Remaining Regents  \
# count                                         420.000000
# mean                                            2.733024
# std                                             1.355355
# min                                             0.000000
# 25%                                             1.907500
# 50%                                             2.735000
# 75%                                             3.705000
# max                                             4.990000
#
#        Metric Score - Weighted Regents Pass Rate, English  \
# count                                         420.000000
# mean                                            3.332619
# std                                             1.148232
# min                                             0.000000
# 25%                                             2.810000
# 50%                                             3.500000
# 75%                                             4.092500
# max                                             4.990000
#
#        Metric Score - Weighted Regents Pass Rate, Math  \
# count                                       420.000000
# mean                                          2.610190
# std                                           1.291837
# min                                           0.000000
# 25%                                           1.767500
# 50%                                           2.705000
# 75%                                           3.530000
# max                                           4.990000
#
#        Metric Score - Weighted Regents Pass Rate, Science  \
# count                                         420.000000
# mean                                            2.575619
# std                                             1.216997
# min                                             0.000000
# 25%                                             1.900000
# 50%                                             2.690000
# 75%                                             3.430000
# max                                             4.990000
#
#        Metric Score - Weighted Regents Pass Rate, Global History  \
# count                                         420.000000
# mean                                            2.505714
# std                                             1.302213
# min                                             0.000000
# 25%                                             1.760000
# 50%                                             2.515000
# 75%                                             3.427500
# max                                             4.990000
#
#        Metric Score - Weighted Regents Pass Rate, US History  \
# count                                         420.000000
# mean                                            2.868786
# std                                             1.421521
# min                                             0.000000
# 25%                                             2.240000
# 50%                                             3.200000
# 75%                                             3.895000
# max                                             4.990000
#
#        Metric Score - Graduation Rate, 4 year  \
# count                              420.000000
# mean                                 2.963548
# std                                  1.333142
# min                                  0.000000
# 25%                                  2.410000
# 50%                                  3.035000
# 75%                                  4.042500
# max                                  4.990000
#
#        Metric Score - Graduation Rate, 6 year  \
# count                              420.000000
# mean                                 2.651857
# std                                  1.537991
# min                                  0.000000
# 25%                                  1.757500
# 50%                                  2.830000
# 75%                                  3.862500
# max                                  4.990000
#
#        Metric Score - Weighted Diploma Rate, 4 year  \
# count                                    420.000000
# mean                                       3.082214
# std                                        1.338700
# min                                        0.000000
# 25%                                        2.582500
# 50%                                        3.160000
# 75%                                        4.050000
# max                                        4.990000
#
#        Metric Score - Weighted Diploma Rate, 6 year  \
# count                                    420.000000
# mean                                       3.014286
# std                                        1.555843
# min                                        0.000000
# 25%                                        2.620000
# 50%                                        3.400000
# 75%                                        4.082500
# max                                        4.990000
#
#        Metric Score - College and Career Preparatory Course Index  \
# count                                         420.000000
# mean                                            3.067405
# std                                             1.478975
# min                                             0.000000
# 25%                                             2.285000
# 50%                                             3.105000
# 75%                                             4.290000
# max                                             4.990000
#
#        Metric Score - Four-year College Readiness Index  \
# count                                        420.000000
# mean                                           3.419881
# std                                            1.477863
# min                                            0.000000
# 25%                                            2.725000
# 50%                                            3.725000
# 75%                                            4.690000
# max                                            4.990000
#
#        Metric Score - College Readiness Rate including persistence  \
# count                                         420.000000
# mean                                            2.794571
# std                                             1.519688
# min                                             0.000000
# 25%                                             2.127500
# 50%                                             3.100000
# 75%                                             3.920000
# max                                             4.990000
#
#        Metric Score - Postsecondary Enrollment Rate, 6 months After High School  \
# count                                         420.000000
# mean                                            2.905357
# std                                             1.358066
# min                                             0.000000
# 25%                                             2.440000
# 50%                                             3.125000
# 75%                                             3.862500
# max                                             4.990000
#
#        Metric Score - Postsecondary Enrollment Rate, 18 months After High School  \
# count                                         420.000000
# mean                                            2.725405
# std                                             1.487515
# min                                             0.000000
# 25%                                             2.077500
# 50%                                             3.050000
# 75%                                             3.847500
# max                                             4.990000
#
#         Enrollment  Rigorous Instruction - Percent Positive  \
# count   420.000000                               420.000000
# mean    712.464286                                 0.855405
# std     762.764662                                 0.051734
# min      62.000000                                 0.700000
# 25%     363.750000                                 0.820000
# 50%     470.500000                                 0.860000
# 75%     628.250000                                 0.890000
# max    5447.000000                                 0.970000
#
#        Collaborative Teachers - Percent Positive  \
# count                                 420.000000
# mean                                    0.866167
# std                                     0.076616
# min                                     0.590000
# 25%                                     0.820000
# 50%                                     0.880000
# 75%                                     0.920000
# max                                     0.990000
#
#        Supportive Environment - Percent Positive  \
# count                                 420.000000
# mean                                    0.829405
# std                                     0.052918
# min                                     0.660000
# 25%                                     0.790000
# 50%                                     0.830000
# 75%                                     0.870000
# max                                     1.000000
#
#        Effective School Leadership - Percent Positive  \
# count                                      420.000000
# mean                                         0.821381
# std                                          0.099120
# min                                          0.450000
# 25%                                          0.760000
# 50%                                          0.840000
# 75%                                          0.900000
# max                                          0.980000
#
#        Strong Family-Community Ties - Percent Positive  \
# count                                       420.000000
# mean                                          0.751833
# std                                           0.061257
# min                                           0.610000
# 25%                                           0.710000
# 50%                                           0.750000
# 75%                                           0.790000
# max                                           0.980000
#
#        Trust - Percent Positive  Average Grade 8 English Proficiency  \
# count                420.000000                           420.000000
# mean                   0.886690                             2.437238
# std                    0.054521                             0.398799
# min                    0.640000                             1.730000
# 25%                    0.850000                             2.217500
# 50%                    0.900000                             2.340000
# 75%                    0.930000                             2.560000
# max                    0.980000                             4.010000
#
#        Average Grade 8 Math Proficiency  Percent English Language Learners  \
# count                        420.000000                         420.000000
# mean                           2.352476                           0.126107
# std                            0.397575                           0.190456
# min                            1.860000                           0.000000
# 25%                            2.090000                           0.026000
# 50%                            2.225000                           0.066500
# 75%                            2.460000                           0.130750
# max                            4.170000                           0.923000
#
#        Percent Students with Disabilities  Percent Self-Contained  \
# count                          420.000000              420.000000
# mean                             0.174348                0.025526
# std                              0.076537                0.032435
# min                              0.000000                0.000000
# 25%                              0.131500                0.003000
# 50%                              0.185000                0.010000
# 75%                              0.231000                0.039000
# max                              0.362000                0.176000
#
#        Economic Need Index  Percent in Temp Housing - 4yr  \
# count           420.000000                     420.000000
# mean              0.659579                       0.098907
# std               0.155309                       0.063818
# min               0.204000                       0.003000
# 25%               0.572500                       0.056000
# 50%               0.696500                       0.087000
# 75%               0.782250                       0.130000
# max               0.882000                       0.416000
#
#        Percent HRA Eligible  Percent Asian  Percent Black  Percent Hispanic  \
# count            420.000000     420.000000     420.000000        420.000000
# mean               0.498969       0.103379       0.348307          0.444752
# std                0.142194       0.140437       0.248275          0.243195
# min                0.113000       0.000000       0.000000          0.026000
# 25%                0.413250       0.017000       0.166750          0.218750
# 50%                0.523000       0.045000       0.285000          0.457500
# 75%                0.606000       0.121750       0.469000          0.635500
# max                0.734000       0.889000       0.941000          1.000000
#
#        Percent White  Years of principal experience at this school  \
# count     420.000000                                    420.000000
# mean        0.084429                                      5.190952
# std         0.129176                                      3.674879
# min         0.000000                                      0.000000
# 25%         0.013000                                      2.300000
# 50%         0.027000                                      4.000000
# 75%         0.093250                                      7.900000
# max         0.799000                                     22.800000
#
#        Percent of teachers with 3 or more years of experience  \
# count                                         420.000000
# mean                                            0.709333
# std                                             0.183044
# min                                             0.000000
# 25%                                             0.607500
# 50%                                             0.740000
# 75%                                             0.840000
# max                                             1.000000
#
#        Student Attendance Rate  Percent of Students Chronically Absent  \
# count               420.000000                              420.000000
# mean                  0.875405                                0.358810
# std                   0.055211                                0.158441
# min                   0.710000                                0.010000
# 25%                   0.830000                                0.240000
# 50%                   0.880000                                0.360000
# 75%                   0.920000                                0.480000
# max                   0.980000                                0.970000
#
#        Teacher Attendance Rate
# count               420.000000
# mean                  0.964714
# std                   0.048354
# min                   0.000000
# 25%                   0.960000
# 50%                   0.970000
# 75%                   0.970000
# max                   0.990000

# %%
filtered_cols_b = [
'prob_Former ELL',
       'prob_Not ELL', 'prob_Not SWD', 'SA_score',
       'Metric Score - Percentage Earning 10+ Credits in First Year',
       'Collaborative Teachers - Percent Positive',
       'Supportive Environment - Percent Positive',
       'Trust - Percent Positive', 'Average Grade 8 English Proficiency',
       'Average Grade 8 Math Proficiency', 'Percent English Language Learners',
'Percent in Temp Housing - 4yr',
       'Student Attendance Rate',
       'Teacher Attendance Rate'
]

# %%
bigset[filtered_cols_b].dtypes
# Out:
# prob_Former ELL                                                float64
# prob_Not ELL                                                   float64
# prob_Not SWD                                                   float64
# SA_score                                                       float64
# Metric Score - Percentage Earning 10+ Credits in First Year    float64
# Collaborative Teachers - Percent Positive                      float64
# Supportive Environment - Percent Positive                      float64
# Trust - Percent Positive                                       float64
# Average Grade 8 English Proficiency                            float64
# Average Grade 8 Math Proficiency                               float64
# Percent English Language Learners                              float64
# Percent in Temp Housing - 4yr                                  float64
# Student Attendance Rate                                        float64
# Teacher Attendance Rate                                        float64
# dtype: object

# %%
features_model = sm.OLS(endog=bigset['grad_rate'], exog=sm.add_constant(bigset[filtered_cols_b]) ).fit()

features_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              grad_rate   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.663
# Method:                 Least Squares   F-statistic:                     59.77
# Date:                Fri, 23 Aug 2019   Prob (F-statistic):           2.94e-89
# Time:                        12:56:25   Log-Likelihood:                 465.03
# No. Observations:                 420   AIC:                            -900.1
# Df Residuals:                     405   BIC:                            -839.5
# Df Model:                          14
# Covariance Type:            nonrobust
# ===============================================================================================================================
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------
# const                                                          -1.1148      0.136     -8.219      0.000      -1.381      -0.848
# prob_Former ELL                                                 0.5643      0.095      5.944      0.000       0.378       0.751
# prob_Not ELL                                                    0.6576      0.088      7.513      0.000       0.486       0.830
# prob_Not SWD                                                    0.1798      0.074      2.437      0.015       0.035       0.325
# SA_score                                                        0.0098      0.004      2.541      0.011       0.002       0.017
# Metric Score - Percentage Earning 10+ Credits in First Year     0.0171      0.004      4.135      0.000       0.009       0.025
# Collaborative Teachers - Percent Positive                       0.2140      0.105      2.029      0.043       0.007       0.421
# Supportive Environment - Percent Positive                       0.3891      0.120      3.231      0.001       0.152       0.626
# Trust - Percent Positive                                       -0.3364      0.168     -2.001      0.046      -0.667      -0.006
# Average Grade 8 English Proficiency                             0.1373      0.046      2.986      0.003       0.047       0.228
# Average Grade 8 Math Proficiency                               -0.1111      0.040     -2.805      0.005      -0.189      -0.033
# Percent English Language Learners                               0.4292      0.095      4.541      0.000       0.243       0.615
# Percent in Temp Housing - 4yr                                  -0.3354      0.118     -2.832      0.005      -0.568      -0.103
# Student Attendance Rate                                         0.6515      0.127      5.125      0.000       0.402       0.901
# Teacher Attendance Rate                                         0.2278      0.083      2.738      0.006       0.064       0.391
# ==============================================================================
# Omnibus:                      147.368   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              990.182
# Skew:                          -1.329   Prob(JB):                    9.65e-216
# Kurtosis:                      10.037   Cond. No.                         327.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
checkresiduals(bigset, 'grad_rate', features_model)

# %%
bigset.boxplot(['grad_rate'])

# %%
poly = PolynomialFeatures(2)
poly_data = poly.fit_transform(bigset[filtered_cols_b])
poly_columns = poly.get_feature_names(bigset[filtered_cols_b].columns)
poly_features = pd.DataFrame(poly_data, columns=poly_columns, index=bigset.index)
# scaler.fit(poly_features)
# scaled_features = scaler.transform(poly_features)

poly_scaled_features = pd.DataFrame(poly_features, columns=poly_columns, index=bigset.index)

# %%
poly_scaled_features.columns
# Out:
# Index(['1', 'prob_Former ELL', 'prob_Not ELL', 'prob_Not SWD', 'SA_score',
#        'Metric Score - Percentage Earning 10+ Credits in First Year',
#        'Collaborative Teachers - Percent Positive',
#        'Supportive Environment - Percent Positive', 'Trust - Percent Positive',
#        'Average Grade 8 English Proficiency',
#        ...
#        'Percent English Language Learners^2',
#        'Percent English Language Learners Percent in Temp Housing - 4yr',
#        'Percent English Language Learners Student Attendance Rate',
#        'Percent English Language Learners Teacher Attendance Rate',
#        'Percent in Temp Housing - 4yr^2',
#        'Percent in Temp Housing - 4yr Student Attendance Rate',
#        'Percent in Temp Housing - 4yr Teacher Attendance Rate',
#        'Student Attendance Rate^2',
#        'Student Attendance Rate Teacher Attendance Rate',
#        'Teacher Attendance Rate^2'],
#       dtype='object', length=120)

# %%
poly_scaled_features = poly_scaled_features.drop(['1'], axis=1)

# %%
poly_scaled_features_model = sm.OLS(endog=merged_set['grad_rate'], exog=sm.add_constant(poly_scaled_features)).fit()

poly_scaled_features_model.summary()
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              grad_rate   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                     10.53
# Date:                Fri, 23 Aug 2019   Prob (F-statistic):           9.94e-61
# Time:                        13:02:44   Log-Likelihood:                 575.06
# No. Observations:                 420   AIC:                            -910.1
# Df Residuals:                     300   BIC:                            -425.3
# Df Model:                         119
# Covariance Type:            nonrobust
# =========================================================================================================================================================================
#                                                                                                             coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                   -24.3716     12.905     -1.889      0.060     -49.767       1.024
# prob_Former ELL                                                                                          24.7832     15.134      1.638      0.103      -4.999      54.565
# prob_Not ELL                                                                                             12.1531      9.897      1.228      0.220      -7.324      31.630
# prob_Not SWD                                                                                              5.4702      8.249      0.663      0.508     -10.763      21.704
# SA_score                                                                                                  0.1242      0.461      0.270      0.788      -0.782       1.031
# Metric Score - Percentage Earning 10+ Credits in First Year                                              -0.3750      0.416     -0.901      0.368      -1.194       0.444
# Collaborative Teachers - Percent Positive                                                                -1.4453     12.017     -0.120      0.904     -25.094      22.204
# Supportive Environment - Percent Positive                                                                -4.8539     13.082     -0.371      0.711     -30.599      20.891
# Trust - Percent Positive                                                                                 16.7919     20.895      0.804      0.422     -24.328      57.912
# Average Grade 8 English Proficiency                                                                       1.4721      5.711      0.258      0.797      -9.768      12.712
# Average Grade 8 Math Proficiency                                                                         -1.5407      4.666     -0.330      0.742     -10.724       7.642
# Percent English Language Learners                                                                         0.8190     11.384      0.072      0.943     -21.583      23.221
# Percent in Temp Housing - 4yr                                                                            14.9552     14.768      1.013      0.312     -14.107      44.018
# Student Attendance Rate                                                                                   7.0614     12.483      0.566      0.572     -17.503      31.626
# Teacher Attendance Rate                                                                                  16.3163     13.890      1.175      0.241     -11.017      43.650
# prob_Former ELL^2                                                                                         1.8561      1.443      1.286      0.199      -0.984       4.697
# prob_Former ELL prob_Not ELL                                                                              5.5777      2.157      2.586      0.010       1.333       9.823
# prob_Former ELL prob_Not SWD                                                                             -6.9412      2.531     -2.743      0.006     -11.922      -1.961
# prob_Former ELL SA_score                                                                                  0.1057      0.153      0.691      0.490      -0.195       0.407
# prob_Former ELL Metric Score - Percentage Earning 10+ Credits in First Year                               0.1800      0.142      1.268      0.206      -0.099       0.459
# prob_Former ELL Collaborative Teachers - Percent Positive                                                -1.5617      3.459     -0.452      0.652      -8.368       5.245
# prob_Former ELL Supportive Environment - Percent Positive                                                -4.1232      3.950     -1.044      0.297     -11.896       3.650
# prob_Former ELL Trust - Percent Positive                                                                  2.5930      6.266      0.414      0.679      -9.738      14.924
# prob_Former ELL Average Grade 8 English Proficiency                                                       0.1598      1.734      0.092      0.927      -3.252       3.571
# prob_Former ELL Average Grade 8 Math Proficiency                                                          1.0258      1.410      0.728      0.467      -1.748       3.800
# prob_Former ELL Percent English Language Learners                                                         4.2096      2.480      1.698      0.091      -0.670       9.089
# prob_Former ELL Percent in Temp Housing - 4yr                                                             7.3920      3.127      2.364      0.019       1.238      13.546
# prob_Former ELL Student Attendance Rate                                                                  -4.4453      4.531     -0.981      0.327     -13.363       4.472
# prob_Former ELL Teacher Attendance Rate                                                                 -22.4605     16.138     -1.392      0.165     -54.218       9.297
# prob_Not ELL^2                                                                                            1.6581      1.281      1.294      0.197      -0.863       4.179
# prob_Not ELL prob_Not SWD                                                                                -1.5961      2.226     -0.717      0.474      -5.976       2.784
# prob_Not ELL SA_score                                                                                    -0.1265      0.135     -0.937      0.350      -0.392       0.139
# prob_Not ELL Metric Score - Percentage Earning 10+ Credits in First Year                                 -0.0704      0.117     -0.604      0.546      -0.300       0.159
# prob_Not ELL Collaborative Teachers - Percent Positive                                                   -2.5501      2.834     -0.900      0.369      -8.127       3.027
# prob_Not ELL Supportive Environment - Percent Positive                                                    3.6793      3.437      1.071      0.285      -3.084      10.442
# prob_Not ELL Trust - Percent Positive                                                                     0.1383      4.924      0.028      0.978      -9.551       9.827
# prob_Not ELL Average Grade 8 English Proficiency                                                         -1.0523      2.176     -0.484      0.629      -5.335       3.230
# prob_Not ELL Average Grade 8 Math Proficiency                                                             0.3964      1.785      0.222      0.824      -3.117       3.909
# prob_Not ELL Percent English Language Learners                                                           -2.0052      2.668     -0.752      0.453      -7.255       3.244
# prob_Not ELL Percent in Temp Housing - 4yr                                                                3.5130      3.038      1.156      0.249      -2.466       9.492
# prob_Not ELL Student Attendance Rate                                                                     -0.7706      3.657     -0.211      0.833      -7.968       6.426
# prob_Not ELL Teacher Attendance Rate                                                                    -11.7861     10.669     -1.105      0.270     -32.782       9.210
# prob_Not SWD^2                                                                                           -0.8709      1.032     -0.844      0.399      -2.902       1.160
# prob_Not SWD SA_score                                                                                     0.0313      0.079      0.395      0.693      -0.125       0.187
# prob_Not SWD Metric Score - Percentage Earning 10+ Credits in First Year                                  0.2491      0.090      2.777      0.006       0.073       0.426
# prob_Not SWD Collaborative Teachers - Percent Positive                                                    1.2239      2.310      0.530      0.597      -3.321       5.769
# prob_Not SWD Supportive Environment - Percent Positive                                                   -0.3797      2.565     -0.148      0.882      -5.427       4.667
# prob_Not SWD Trust - Percent Positive                                                                    -1.4884      3.627     -0.410      0.682      -8.626       5.649
# prob_Not SWD Average Grade 8 English Proficiency                                                         -1.4161      1.062     -1.333      0.184      -3.507       0.674
# prob_Not SWD Average Grade 8 Math Proficiency                                                             1.5064      0.919      1.639      0.102      -0.302       3.315
# prob_Not SWD Percent English Language Learners                                                            1.2462      2.414      0.516      0.606      -3.505       5.998
# prob_Not SWD Percent in Temp Housing - 4yr                                                               -5.5369      2.976     -1.861      0.064     -11.393       0.320
# prob_Not SWD Student Attendance Rate                                                                     -6.2880      2.979     -2.110      0.036     -12.151      -0.425
# prob_Not SWD Teacher Attendance Rate                                                                      3.4607      9.419      0.367      0.714     -15.074      21.996
# SA_score^2                                                                                                0.0112      0.004      2.716      0.007       0.003       0.019
# SA_score Metric Score - Percentage Earning 10+ Credits in First Year                                      0.0058      0.005      1.273      0.204      -0.003       0.015
# SA_score Collaborative Teachers - Percent Positive                                                       -0.4723      0.134     -3.516      0.001      -0.737      -0.208
# SA_score Supportive Environment - Percent Positive                                                       -0.4396      0.156     -2.814      0.005      -0.747      -0.132
# SA_score Trust - Percent Positive                                                                         0.7846      0.243      3.229      0.001       0.306       1.263
# SA_score Average Grade 8 English Proficiency                                                              0.0704      0.051      1.371      0.171      -0.031       0.172
# SA_score Average Grade 8 Math Proficiency                                                                -0.0303      0.047     -0.643      0.521      -0.123       0.063
# SA_score Percent English Language Learners                                                               -0.2108      0.127     -1.655      0.099      -0.461       0.040
# SA_score Percent in Temp Housing - 4yr                                                                    0.2056      0.150      1.371      0.171      -0.089       0.501
# SA_score Student Attendance Rate                                                                         -0.0508      0.151     -0.337      0.736      -0.348       0.246
# SA_score Teacher Attendance Rate                                                                         -0.0779      0.473     -0.165      0.869      -1.008       0.852
# Metric Score - Percentage Earning 10+ Credits in First Year^2                                             0.0030      0.004      0.671      0.502      -0.006       0.012
# Metric Score - Percentage Earning 10+ Credits in First Year Collaborative Teachers - Percent Positive     0.2040      0.119      1.718      0.087      -0.030       0.438
# Metric Score - Percentage Earning 10+ Credits in First Year Supportive Environment - Percent Positive     0.3787      0.142      2.670      0.008       0.100       0.658
# Metric Score - Percentage Earning 10+ Credits in First Year Trust - Percent Positive                     -0.3560      0.205     -1.738      0.083      -0.759       0.047
# Metric Score - Percentage Earning 10+ Credits in First Year Average Grade 8 English Proficiency          -0.0229      0.051     -0.450      0.653      -0.123       0.077
# Metric Score - Percentage Earning 10+ Credits in First Year Average Grade 8 Math Proficiency             -0.0605      0.049     -1.241      0.216      -0.157       0.035
# Metric Score - Percentage Earning 10+ Credits in First Year Percent English Language Learners            -0.2533      0.131     -1.940      0.053      -0.510       0.004
# Metric Score - Percentage Earning 10+ Credits in First Year Percent in Temp Housing - 4yr                -0.0247      0.172     -0.144      0.886      -0.363       0.313
# Metric Score - Percentage Earning 10+ Credits in First Year Student Attendance Rate                      -0.1805      0.148     -1.219      0.224      -0.472       0.111
# Metric Score - Percentage Earning 10+ Credits in First Year Teacher Attendance Rate                       0.4223      0.439      0.962      0.337      -0.442       1.286
# Collaborative Teachers - Percent Positive^2                                                              -3.9570      2.026     -1.953      0.052      -7.945       0.031
# Collaborative Teachers - Percent Positive Supportive Environment - Percent Positive                       3.3020      3.091      1.068      0.286      -2.782       9.386
# Collaborative Teachers - Percent Positive Trust - Percent Positive                                        7.8759      5.610      1.404      0.161      -3.163      18.915
# Collaborative Teachers - Percent Positive Average Grade 8 English Proficiency                            -0.4273      1.693     -0.252      0.801      -3.759       2.904
# Collaborative Teachers - Percent Positive Average Grade 8 Math Proficiency                                0.6927      1.454      0.476      0.634      -2.169       3.554
# Collaborative Teachers - Percent Positive Percent English Language Learners                              -3.9319      3.131     -1.256      0.210     -10.093       2.230
# Collaborative Teachers - Percent Positive Percent in Temp Housing - 4yr                                   4.1230      3.715      1.110      0.268      -3.188      11.434
# Collaborative Teachers - Percent Positive Student Attendance Rate                                        -0.4819      3.907     -0.123      0.902      -8.171       7.207
# Collaborative Teachers - Percent Positive Teacher Attendance Rate                                         0.7830     12.534      0.062      0.950     -23.882      25.448
# Supportive Environment - Percent Positive^2                                                               4.0908      2.754      1.486      0.138      -1.328       9.509
# Supportive Environment - Percent Positive Trust - Percent Positive                                      -12.2256      5.767     -2.120      0.035     -23.574      -0.878
# Supportive Environment - Percent Positive Average Grade 8 English Proficiency                            -1.2868      1.752     -0.734      0.463      -4.735       2.162
# Supportive Environment - Percent Positive Average Grade 8 Math Proficiency                               -0.1213      1.449     -0.084      0.933      -2.973       2.731
# Supportive Environment - Percent Positive Percent English Language Learners                               6.6643      3.553      1.875      0.062      -0.328      13.657
# Supportive Environment - Percent Positive Percent in Temp Housing - 4yr                                  -1.6200      4.645     -0.349      0.728     -10.760       7.520
# Supportive Environment - Percent Positive Student Attendance Rate                                         1.0443      4.623      0.226      0.821      -8.053      10.142
# Supportive Environment - Percent Positive Teacher Attendance Rate                                         6.0298     13.435      0.449      0.654     -20.409      32.469
# Trust - Percent Positive^2                                                                               -1.7111      4.624     -0.370      0.712     -10.811       7.388
# Trust - Percent Positive Average Grade 8 English Proficiency                                              0.1424      2.416      0.059      0.953      -4.612       4.897
# Trust - Percent Positive Average Grade 8 Math Proficiency                                                 0.7400      2.087      0.355      0.723      -3.368       4.848
# Trust - Percent Positive Percent English Language Learners                                                1.4366      4.877      0.295      0.769      -8.161      11.034
# Trust - Percent Positive Percent in Temp Housing - 4yr                                                   -3.3852      5.804     -0.583      0.560     -14.807       8.036
# Trust - Percent Positive Student Attendance Rate                                                          0.9005      6.506      0.138      0.890     -11.903      13.704
# Trust - Percent Positive Teacher Attendance Rate                                                        -14.4197     21.200     -0.680      0.497     -56.139      27.300
# Average Grade 8 English Proficiency^2                                                                    -0.1572      0.383     -0.410      0.682      -0.912       0.597
# Average Grade 8 English Proficiency Average Grade 8 Math Proficiency                                      0.2020      0.599      0.337      0.736      -0.978       1.381
# Average Grade 8 English Proficiency Percent English Language Learners                                    -1.9070      2.183     -0.874      0.383      -6.203       2.389
# Average Grade 8 English Proficiency Percent in Temp Housing - 4yr                                        -0.9515      1.618     -0.588      0.557      -4.135       2.232
# Average Grade 8 English Proficiency Student Attendance Rate                                              -0.4506      2.110     -0.214      0.831      -4.602       3.701
# Average Grade 8 English Proficiency Teacher Attendance Rate                                               2.9685      5.759      0.515      0.607      -8.365      14.303
# Average Grade 8 Math Proficiency^2                                                                       -0.1270      0.276     -0.460      0.646      -0.670       0.416
# Average Grade 8 Math Proficiency Percent English Language Learners                                       -0.7732      1.773     -0.436      0.663      -4.261       2.715
# Average Grade 8 Math Proficiency Percent in Temp Housing - 4yr                                            2.0948      1.542      1.358      0.175      -0.940       5.130
# Average Grade 8 Math Proficiency Student Attendance Rate                                                  2.0793      1.826      1.139      0.256      -1.515       5.673
# Average Grade 8 Math Proficiency Teacher Attendance Rate                                                 -3.0012      4.906     -0.612      0.541     -12.655       6.653
# Percent English Language Learners^2                                                                      -4.6898      1.938     -2.420      0.016      -8.503      -0.876
# Percent English Language Learners Percent in Temp Housing - 4yr                                           2.9261      3.502      0.835      0.404      -3.966       9.818
# Percent English Language Learners Student Attendance Rate                                                 3.1728      4.041      0.785      0.433      -4.779      11.125
# Percent English Language Learners Teacher Attendance Rate                                                 2.5573     12.331      0.207      0.836     -21.709      26.824
# Percent in Temp Housing - 4yr^2                                                                          -0.7296      2.356     -0.310      0.757      -5.367       3.908
# Percent in Temp Housing - 4yr Student Attendance Rate                                                    -4.5404      4.872     -0.932      0.352     -14.128       5.047
# Percent in Temp Housing - 4yr Teacher Attendance Rate                                                   -13.2172     15.857     -0.834      0.405     -44.422      17.987
# Student Attendance Rate^2                                                                                -0.9803      3.081     -0.318      0.751      -7.043       5.082
# Student Attendance Rate Teacher Attendance Rate                                                          -3.3761     13.147     -0.257      0.798     -29.248      22.496
# Teacher Attendance Rate^2                                                                                 1.2794      1.164      1.099      0.273      -1.011       3.570
# ==============================================================================
# Omnibus:                       54.224   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              199.330
# Skew:                          -0.514   Prob(JB):                     5.20e-44
# Kurtosis:                       6.214   Cond. No.                     3.36e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.36e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
trimmedset = bigset[bigset['grad_rate'] >= .5]

# %%
trimmedset.columns
# Out:
# Index(['DBN', 'School Name_x', 'total_stud', 'grad_rate', 'prob_Former ELL',
#        'prob_Not ELL', 'prob_Not SWD', 'prob_Asian', 'prob_Black',
#        'prob_Hispanic', 'prob_Native American', 'prob_White', 'prob_Female',
#        'prob_Male', 'prob_Econ Disadv', 'prob_Not Econ Disadv', 'SA_score',
#        'Metric Score - Percentage Earning 10+ Credits in First Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in First Year',
#        'Metric Score - Percentage Earning 10+ Credits in Second Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Second Year',
#        'Metric Score - Percentage Earning 10+ Credits in Third Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Third Year',
#        'Metric Score - Average Completion Rate for Remaining Regents',
#        'Metric Score - Weighted Regents Pass Rate, English',
#        'Metric Score - Weighted Regents Pass Rate, Math',
#        'Metric Score - Weighted Regents Pass Rate, Science',
#        'Metric Score - Weighted Regents Pass Rate, Global History',
#        'Metric Score - Weighted Regents Pass Rate, US History',
#        'Metric Score - Graduation Rate, 4 year',
#        'Metric Score - Graduation Rate, 6 year',
#        'Metric Score - Weighted Diploma Rate, 4 year',
#        'Metric Score - Weighted Diploma Rate, 6 year',
#        'Metric Score - College and Career Preparatory Course Index',
#        'Metric Score - Four-year College Readiness Index',
#        'Metric Score - College Readiness Rate including persistence',
#        'Metric Score - Postsecondary Enrollment Rate, 6 months After High School',
#        'Metric Score - Postsecondary Enrollment Rate, 18 months After High School',
#        'Metric Value - Non-Dropout Rate, 4 year',
#        'Metric Value - Non-Dropout Rate, 6 year', 'Enrollment',
#        'Rigorous Instruction - Percent Positive',
#        'Collaborative Teachers - Percent Positive',
#        'Supportive Environment - Percent Positive',
#        'Effective School Leadership - Percent Positive',
#        'Strong Family-Community Ties - Percent Positive',
#        'Trust - Percent Positive', 'Average Grade 8 English Proficiency',
#        'Average Grade 8 Math Proficiency', 'Percent English Language Learners',
#        'Percent Students with Disabilities', 'Percent Self-Contained',
#        'Economic Need Index', 'Percent in Temp Housing - 4yr',
#        'Percent HRA Eligible', 'Percent Asian', 'Percent Black',
#        'Percent Hispanic', 'Percent White',
#        'Years of principal experience at this school',
#        'Percent of teachers with 3 or more years of experience',
#        'Student Attendance Rate', 'Percent of Students Chronically Absent',
#        'Teacher Attendance Rate'],
#       dtype='object')

# %%
# 'prob_Not SWD', 'Trust - Percent Positive', 'Collaborative Teachers - Percent Positive',
filtered_cols_tt = [
'prob_Former ELL',
       'prob_Not ELL', 'SA_score',
       'Metric Score - Percentage Earning 10+ Credits in First Year',
       'Supportive Environment - Percent Positive',
       'Average Grade 8 English Proficiency', 'Percent English Language Learners',
'Percent in Temp Housing - 4yr',
       'Student Attendance Rate',
       'Teacher Attendance Rate'
]

# %%
features_model = sm.OLS(endog=trimmedset['grad_rate'], exog=sm.add_constant(trimmedset[filtered_cols_tt]) ).fit()

features_model.summary()
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              grad_rate   R-squared:                       0.695
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     91.10
# Date:                Fri, 23 Aug 2019   Prob (F-statistic):           1.63e-96
# Time:                        11:15:31   Log-Likelihood:                 534.07
# No. Observations:                 410   AIC:                            -1046.
# Df Residuals:                     399   BIC:                            -1002.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================================================================
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------
# const                                                          -0.8649      0.108     -7.978      0.000      -1.078      -0.652
# prob_Former ELL                                                 0.2975      0.077      3.871      0.000       0.146       0.449
# prob_Not ELL                                                    0.5254      0.078      6.778      0.000       0.373       0.678
# SA_score                                                        0.0086      0.003      2.728      0.007       0.002       0.015
# Metric Score - Percentage Earning 10+ Credits in First Year     0.0180      0.003      5.258      0.000       0.011       0.025
# Supportive Environment - Percent Positive                       0.2235      0.078      2.860      0.004       0.070       0.377
# Average Grade 8 English Proficiency                             0.0469      0.015      3.174      0.002       0.018       0.076
# Percent English Language Learners                               0.4109      0.080      5.105      0.000       0.253       0.569
# Percent in Temp Housing - 4yr                                  -0.3683      0.097     -3.810      0.000      -0.558      -0.178
# Student Attendance Rate                                         0.6355      0.100      6.339      0.000       0.438       0.833
# Teacher Attendance Rate                                         0.2678      0.068      3.931      0.000       0.134       0.402
# ==============================================================================
# Omnibus:                        7.113   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):                8.080
# Skew:                          -0.208   Prob(JB):                       0.0176
# Kurtosis:                       3.548   Cond. No.                         235.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
checkresiduals(trimmedset,'grad_rate', features_model)

# %%
sns.distplot(trimmedset['grad_rate'], fit=norm, bins=20, kde=False, color = 'red')

# %%
len(poly_scaled_features.columns)
# Out:
# 65

# %%
poly_scaled_features_model = sm.OLS(endog=trimmedset['grad_rate'], exog=sm.add_constant(poly_scaled_features)).fit()

poly_scaled_features_model.summary()
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              grad_rate   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     18.26
# Date:                Fri, 23 Aug 2019   Prob (F-statistic):           9.89e-79
# Time:                        11:16:14   Log-Likelihood:                 596.41
# No. Observations:                 410   AIC:                            -1061.
# Df Residuals:                     344   BIC:                            -795.8
# Df Model:                          65
# Covariance Type:            nonrobust
# =========================================================================================================================================================================
#                                                                                                             coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                    -6.2442      9.465     -0.660      0.510     -24.860      12.372
# prob_Former ELL                                                                                          13.0831     10.467      1.250      0.212      -7.504      33.670
# prob_Not ELL                                                                                              8.0704      9.162      0.881      0.379      -9.951      26.091
# SA_score                                                                                                 -0.2470      0.347     -0.711      0.477      -0.930       0.436
# Metric Score - Percentage Earning 10+ Credits in First Year                                               0.3499      0.316      1.107      0.269      -0.272       0.971
# Supportive Environment - Percent Positive                                                                -3.3634      7.729     -0.435      0.664     -18.565      11.839
# Average Grade 8 English Proficiency                                                                       1.0030      1.649      0.608      0.543      -2.241       4.247
# Percent English Language Learners                                                                         8.0147      9.282      0.863      0.388     -10.242      26.271
# Percent in Temp Housing - 4yr                                                                            -2.2224     10.246     -0.217      0.828     -22.375      17.930
# Student Attendance Rate                                                                                  -6.1986      8.733     -0.710      0.478     -23.374      10.977
# Teacher Attendance Rate                                                                                   9.6926      9.892      0.980      0.328      -9.763      29.148
# prob_Former ELL^2                                                                                         0.2259      0.954      0.237      0.813      -1.650       2.102
# prob_Former ELL prob_Not ELL                                                                              2.6050      1.584      1.645      0.101      -0.510       5.720
# prob_Former ELL SA_score                                                                                  0.0757      0.120      0.630      0.529      -0.161       0.312
# prob_Former ELL Metric Score - Percentage Earning 10+ Credits in First Year                               0.0801      0.107      0.749      0.454      -0.130       0.290
# prob_Former ELL Supportive Environment - Percent Positive                                                 2.8530      2.402      1.188      0.236      -1.872       7.578
# prob_Former ELL Average Grade 8 English Proficiency                                                       0.5645      0.874      0.646      0.519      -1.155       2.284
# prob_Former ELL Percent English Language Learners                                                         1.5817      1.642      0.963      0.336      -1.648       4.812
# prob_Former ELL Percent in Temp Housing - 4yr                                                             3.2296      2.208      1.463      0.144      -1.113       7.572
# prob_Former ELL Student Attendance Rate                                                                  -2.5116      3.363     -0.747      0.456      -9.125       4.102
# prob_Former ELL Teacher Attendance Rate                                                                 -17.7495     11.657     -1.523      0.129     -40.678       5.179
# prob_Not ELL^2                                                                                            2.9814      1.115      2.675      0.008       0.789       5.174
# prob_Not ELL SA_score                                                                                     0.0258      0.106      0.243      0.808      -0.183       0.235
# prob_Not ELL Metric Score - Percentage Earning 10+ Credits in First Year                                 -0.1110      0.094     -1.185      0.237      -0.295       0.073
# prob_Not ELL Supportive Environment - Percent Positive                                                    2.3887      2.325      1.027      0.305      -2.185       6.962
# prob_Not ELL Average Grade 8 English Proficiency                                                         -0.4622      0.916     -0.505      0.614      -2.263       1.339
# prob_Not ELL Percent English Language Learners                                                            3.9910      2.347      1.700      0.090      -0.625       8.607
# prob_Not ELL Percent in Temp Housing - 4yr                                                               -0.8101      2.483     -0.326      0.744      -5.693       4.073
# prob_Not ELL Student Attendance Rate                                                                      1.1388      3.057      0.372      0.710      -4.875       7.152
# prob_Not ELL Teacher Attendance Rate                                                                    -15.0040      9.786     -1.533      0.126     -34.251       4.243
# SA_score^2                                                                                                0.0073      0.003      2.213      0.028       0.001       0.014
# SA_score Metric Score - Percentage Earning 10+ Credits in First Year                                      0.0024      0.003      0.711      0.477      -0.004       0.009
# SA_score Supportive Environment - Percent Positive                                                       -0.0150      0.095     -0.157      0.875      -0.202       0.172
# SA_score Average Grade 8 English Proficiency                                                              0.0022      0.023      0.095      0.924      -0.042       0.047
# SA_score Percent English Language Learners                                                               -0.0547      0.095     -0.573      0.567      -0.242       0.133
# SA_score Percent in Temp Housing - 4yr                                                                    0.1316      0.104      1.268      0.206      -0.073       0.336
# SA_score Student Attendance Rate                                                                         -0.0789      0.113     -0.695      0.487      -0.302       0.144
# SA_score Teacher Attendance Rate                                                                          0.2683      0.353      0.760      0.448      -0.426       0.963
# Metric Score - Percentage Earning 10+ Credits in First Year^2                                             0.0024      0.003      0.703      0.483      -0.004       0.009
# Metric Score - Percentage Earning 10+ Credits in First Year Supportive Environment - Percent Positive     0.0391      0.089      0.439      0.661      -0.136       0.214
# Metric Score - Percentage Earning 10+ Credits in First Year Average Grade 8 English Proficiency          -0.0260      0.023     -1.123      0.262      -0.072       0.020
# Metric Score - Percentage Earning 10+ Credits in First Year Percent English Language Learners            -0.1561      0.101     -1.550      0.122      -0.354       0.042
# Metric Score - Percentage Earning 10+ Credits in First Year Percent in Temp Housing - 4yr                -0.0782      0.121     -0.645      0.520      -0.317       0.160
# Metric Score - Percentage Earning 10+ Credits in First Year Student Attendance Rate                      -0.0594      0.111     -0.537      0.591      -0.277       0.158
# Metric Score - Percentage Earning 10+ Credits in First Year Teacher Attendance Rate                      -0.1641      0.332     -0.494      0.622      -0.817       0.489
# Supportive Environment - Percent Positive^2                                                              -1.1249      1.219     -0.923      0.357      -3.522       1.273
# Supportive Environment - Percent Positive Average Grade 8 English Proficiency                            -0.3582      0.386     -0.929      0.354      -1.117       0.400
# Supportive Environment - Percent Positive Percent English Language Learners                               2.3628      2.418      0.977      0.329      -2.394       7.119
# Supportive Environment - Percent Positive Percent in Temp Housing - 4yr                                  -2.6757      2.863     -0.935      0.351      -8.307       2.955
# Supportive Environment - Percent Positive Student Attendance Rate                                         2.4457      2.606      0.939      0.349      -2.679       7.570
# Supportive Environment - Percent Positive Teacher Attendance Rate                                         1.8455      7.953      0.232      0.817     -13.798      17.489
# Average Grade 8 English Proficiency^2                                                                    -0.0887      0.052     -1.718      0.087      -0.190       0.013
# Average Grade 8 English Proficiency Percent English Language Learners                                    -1.8421      0.868     -2.122      0.035      -3.549      -0.135
# Average Grade 8 English Proficiency Percent in Temp Housing - 4yr                                         0.2652      0.579      0.458      0.647      -0.874       1.405
# Average Grade 8 English Proficiency Student Attendance Rate                                               0.5572      0.759      0.734      0.463      -0.936       2.050
# Average Grade 8 English Proficiency Teacher Attendance Rate                                              -0.0935      1.464     -0.064      0.949      -2.974       2.787
# Percent English Language Learners^2                                                                       0.6091      1.519      0.401      0.689      -2.378       3.596
# Percent English Language Learners Percent in Temp Housing - 4yr                                          -2.2136      2.722     -0.813      0.417      -7.568       3.141
# Percent English Language Learners Student Attendance Rate                                                 0.6780      3.255      0.208      0.835      -5.725       7.080
# Percent English Language Learners Teacher Attendance Rate                                                -8.8036      9.978     -0.882      0.378     -28.429      10.822
# Percent in Temp Housing - 4yr^2                                                                           1.2575      1.948      0.645      0.519      -2.574       5.089
# Percent in Temp Housing - 4yr Student Attendance Rate                                                     2.6040      3.631      0.717      0.474      -4.539       9.747
# Percent in Temp Housing - 4yr Teacher Attendance Rate                                                     1.6183     11.326      0.143      0.886     -20.658      23.895
# Student Attendance Rate^2                                                                                -0.0886      2.224     -0.040      0.968      -4.463       4.286
# Student Attendance Rate Teacher Attendance Rate                                                           2.7090      9.008      0.301      0.764     -15.008      20.426
# Teacher Attendance Rate^2                                                                                 0.7388      0.888      0.832      0.406      -1.009       2.486
# ==============================================================================
# Omnibus:                        9.595   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               14.390
# Skew:                          -0.157   Prob(JB):                     0.000750
# Kurtosis:                       3.863   Cond. No.                     2.09e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
checkresiduals(trimmedset,'grad_rate', poly_scaled_features_model)

# %%
trimmedset[filtered_cols_t].describe()
# Out:
#        prob_Former ELL  prob_Not ELL    SA_score  \
# count       410.000000    410.000000  410.000000
# mean          0.070878      0.840707    3.115951
# std           0.087657      0.204491    1.211328
# min           0.000000      0.010000    0.000000
# 25%           0.020000      0.810000    2.772500
# 50%           0.050000      0.900000    3.340000
# 75%           0.090000      0.960000    3.870000
# max           0.600000      1.000000    4.990000
#
#        Metric Score - Percentage Earning 10+ Credits in First Year  \
# count                                         410.000000
# mean                                            3.363756
# std                                             1.160724
# min                                             0.000000
# 25%                                             2.670000
# 50%                                             3.550000
# 75%                                             4.287500
# max                                             4.990000
#
#        Supportive Environment - Percent Positive  \
# count                                 410.000000
# mean                                    0.830659
# std                                     0.052468
# min                                     0.660000
# 25%                                     0.790000
# 50%                                     0.830000
# 75%                                     0.870000
# max                                     1.000000
#
#        Average Grade 8 English Proficiency  Average Grade 8 Math Proficiency  \
# count                           410.000000                        410.000000
# mean                              2.445293                          2.360439
# std                               0.399995                          0.398953
# min                               1.730000                          1.860000
# 25%                               2.220000                          2.100000
# 50%                               2.340000                          2.230000
# 75%                               2.560000                          2.467500
# max                               4.010000                          4.170000
#
#        Percent English Language Learners  Percent in Temp Housing - 4yr  \
# count                         410.000000                     410.000000
# mean                            0.123888                       0.097446
# std                             0.189194                       0.063282
# min                             0.000000                       0.003000
# 25%                             0.026000                       0.056000
# 50%                             0.064000                       0.085000
# 75%                             0.127750                       0.128000
# max                             0.923000                       0.416000
#
#        Student Attendance Rate  Teacher Attendance Rate
# count               410.000000               410.000000
# mean                  0.877122                 0.964683
# std                   0.054410                 0.048895
# min                   0.720000                 0.000000
# 25%                   0.840000                 0.960000
# 50%                   0.880000                 0.970000
# 75%                   0.920000                 0.970000
# max                   0.980000                 0.990000

# %%
sns.jointplot(x='SA_score', y='grad_rate', data=biggerset, kind="reg")

# %%
betterset = trimmedset[trimmedset['SA_score'] > 0]

# %%
sns.jointplot(x='SA_score', y='grad_rate', data=trimmedset, kind="reg")

# %%
trimmedset.columns
# Out:
# Index(['DBN', 'School Name_x', 'total_stud', 'grad_rate', 'prob_Former ELL',
#        'prob_Not ELL', 'prob_Not SWD', 'prob_Asian', 'prob_Black',
#        'prob_Hispanic', 'prob_Native American', 'prob_White', 'prob_Female',
#        'prob_Male', 'prob_Econ Disadv', 'prob_Not Econ Disadv', 'SA_score',
#        'Metric Score - Percentage Earning 10+ Credits in First Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in First Year',
#        'Metric Score - Percentage Earning 10+ Credits in Second Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Second Year',
#        'Metric Score - Percentage Earning 10+ Credits in Third Year',
#        'Metric Score - Lowest Third School, Percentage Earning 10+ Credits in Third Year',
#        'Metric Score - Average Completion Rate for Remaining Regents',
#        'Metric Score - Weighted Regents Pass Rate, English',
#        'Metric Score - Weighted Regents Pass Rate, Math',
#        'Metric Score - Weighted Regents Pass Rate, Science',
#        'Metric Score - Weighted Regents Pass Rate, Global History',
#        'Metric Score - Weighted Regents Pass Rate, US History',
#        'Metric Score - Graduation Rate, 4 year',
#        'Metric Score - Graduation Rate, 6 year',
#        'Metric Score - Weighted Diploma Rate, 4 year',
#        'Metric Score - Weighted Diploma Rate, 6 year',
#        'Metric Score - College and Career Preparatory Course Index',
#        'Metric Score - Four-year College Readiness Index',
#        'Metric Score - College Readiness Rate including persistence',
#        'Metric Score - Postsecondary Enrollment Rate, 6 months After High School',
#        'Metric Score - Postsecondary Enrollment Rate, 18 months After High School',
#        'Metric Value - Non-Dropout Rate, 4 year',
#        'Metric Value - Non-Dropout Rate, 6 year', 'Enrollment',
#        'Rigorous Instruction - Percent Positive',
#        'Collaborative Teachers - Percent Positive',
#        'Supportive Environment - Percent Positive',
#        'Effective School Leadership - Percent Positive',
#        'Strong Family-Community Ties - Percent Positive',
#        'Trust - Percent Positive', 'Average Grade 8 English Proficiency',
#        'Average Grade 8 Math Proficiency', 'Percent English Language Learners',
#        'Percent Students with Disabilities', 'Percent Self-Contained',
#        'Economic Need Index', 'Percent in Temp Housing - 4yr',
#        'Percent HRA Eligible', 'Percent Asian', 'Percent Black',
#        'Percent Hispanic', 'Percent White',
#        'Years of principal experience at this school',
#        'Percent of teachers with 3 or more years of experience',
#        'Student Attendance Rate', 'Percent of Students Chronically Absent',
#        'Teacher Attendance Rate'],
#       dtype='object')

# %%
Student Attendance Rate

# %%
sns.jointplot(x='Student Attendance Rate', y='grad_rate', data=trimmedset, kind="reg")

# %%
sns.jointplot(x='Average Grade 8 Math Proficiency', y='grad_rate', data=biggerset, kind="reg")

# %%
CorrMtx(biggerset[filtered_cols].corr(), dropDuplicates = True)

# %%
scaler = StandardScaler()
scaler.fit(merged_set[filtered_cols])
scaled_features = scaler.transform(merged_set[filtered_cols])

scaled_features_dataset = pd.DataFrame(scaled_features, columns=filtered_cols, index=dataset.index)
scaled_features_dataset.head()

# %%
poly = PolynomialFeatures(2)
poly_data = poly.fit_transform(merged_set[filtered_cols])
poly_columns = poly.get_feature_names(merged_set[filtered_cols].columns)
poly_features = pd.DataFrame(poly_data, columns=poly_columns, index=dataset.index)
scaler.fit(poly_features)
scaled_features = scaler.transform(poly_features)

poly_scaled_features = pd.DataFrame(scaled_features, columns=poly_columns, index=dataset.index)
poly_scaled_features.head(15)

poly_scaled_features['1'].describe()
# poly_scaled_features = poly_scaled_features.drop(['1'], axis=1)

# %%
# poly_scaled_features_model = sm.OLS(endog=df['price_log'], exog=sm.add_constant(poly_scaled_features)).fit()

poly_scaled_features_model = sm.OLS(endog=merged_set['grad_rate'], exog=sm.add_constant(poly_scaled_features)).fit()

poly_scaled_features_model.summary()
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              grad_rate   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.615
# Method:                 Least Squares   F-statistic:                     11.31
# Date:                Thu, 22 Aug 2019   Prob (F-statistic):           3.96e-55
# Time:                        15:56:09   Log-Likelihood:                 465.76
# No. Observations:                 420   AIC:                            -799.5
# Df Residuals:                     354   BIC:                            -532.9
# Df Model:                          65
# Covariance Type:            nonrobust
# ============================================================================================================================================================================
#                                                                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                        0.8049      0.004    189.705      0.000       0.797       0.813
# 1                                                                                                          1.44e-14   3.68e-14      0.391      0.696    -5.8e-14    8.68e-14
# prob_Former ELL                                                                                              1.3971      0.600      2.327      0.021       0.217       2.578
# prob_Not ELL                                                                                                 0.1019      0.671      0.152      0.879      -1.217       1.421
# prob_Not SWD                                                                                                 0.0057      0.321      0.018      0.986      -0.625       0.636
# prob_Asian                                                                                                   0.3202      1.694      0.189      0.850      -3.012       3.652
# prob_Black                                                                                                   0.5116      2.675      0.191      0.848      -4.750       5.773
# prob_Hispanic                                                                                                0.3165      2.744      0.115      0.908      -5.079       5.712
# prob_White                                                                                                   0.5620      1.424      0.395      0.693      -2.238       3.362
# Metric Score - Weighted Regents Pass Rate, Science                                                           0.2304      0.369      0.625      0.533      -0.495       0.956
# Metric Score - Weighted Regents Pass Rate, US History                                                       -0.3223      0.427     -0.754      0.451      -1.163       0.518
# Metric Score - Four-year College Readiness Index                                                             0.2579      0.301      0.858      0.391      -0.333       0.849
# prob_Former ELL^2                                                                                           -0.0358      0.041     -0.867      0.387      -0.117       0.045
# prob_Former ELL prob_Not ELL                                                                                -0.0307      0.036     -0.847      0.397      -0.102       0.041
# prob_Former ELL prob_Not SWD                                                                                -0.3498      0.156     -2.241      0.026      -0.657      -0.043
# prob_Former ELL prob_Asian                                                                                  -0.2466      0.172     -1.437      0.152      -0.584       0.091
# prob_Former ELL prob_Black                                                                                  -0.1769      0.119     -1.481      0.139      -0.412       0.058
# prob_Former ELL prob_Hispanic                                                                               -0.7171      0.445     -1.610      0.108      -1.593       0.159
# prob_Former ELL prob_White                                                                                  -0.1017      0.076     -1.338      0.182      -0.251       0.048
# prob_Former ELL Metric Score - Weighted Regents Pass Rate, Science                                           0.0550      0.043      1.286      0.199      -0.029       0.139
# prob_Former ELL Metric Score - Weighted Regents Pass Rate, US History                                       -0.0357      0.039     -0.907      0.365      -0.113       0.042
# prob_Former ELL Metric Score - Four-year College Readiness Index                                            -0.0183      0.035     -0.518      0.605      -0.088       0.051
# prob_Not ELL^2                                                                                               0.1741      0.076      2.284      0.023       0.024       0.324
# prob_Not ELL prob_Not SWD                                                                                    0.1318      0.164      0.803      0.423      -0.191       0.455
# prob_Not ELL prob_Asian                                                                                     -0.1183      0.408     -0.290      0.772      -0.921       0.685
# prob_Not ELL prob_Black                                                                                     -0.1815      0.741     -0.245      0.806      -1.638       1.275
# prob_Not ELL prob_Hispanic                                                                                  -0.2561      0.608     -0.421      0.674      -1.452       0.940
# prob_Not ELL prob_White                                                                                     -0.0541      0.426     -0.127      0.899      -0.892       0.783
# prob_Not ELL Metric Score - Weighted Regents Pass Rate, Science                                              0.0109      0.079      0.139      0.889      -0.144       0.165
# prob_Not ELL Metric Score - Weighted Regents Pass Rate, US History                                           0.0526      0.081      0.647      0.518      -0.107       0.213
# prob_Not ELL Metric Score - Four-year College Readiness Index                                               -0.0828      0.057     -1.448      0.148      -0.195       0.030
# prob_Not SWD^2                                                                                               0.0404      0.100      0.405      0.686      -0.156       0.236
# prob_Not SWD prob_Asian                                                                                     -0.1849      0.501     -0.369      0.712      -1.171       0.801
# prob_Not SWD prob_Black                                                                                     -0.1376      0.705     -0.195      0.845      -1.525       1.249
# prob_Not SWD prob_Hispanic                                                                                  -0.0053      0.727     -0.007      0.994      -1.436       1.425
# prob_Not SWD prob_White                                                                                     -0.1463      0.430     -0.340      0.734      -0.992       0.700
# prob_Not SWD Metric Score - Weighted Regents Pass Rate, Science                                              0.1130      0.098      1.156      0.248      -0.079       0.305
# prob_Not SWD Metric Score - Weighted Regents Pass Rate, US History                                          -0.0081      0.102     -0.079      0.937      -0.209       0.193
# prob_Not SWD Metric Score - Four-year College Readiness Index                                               -0.1264      0.078     -1.615      0.107      -0.280       0.028
# prob_Asian^2                                                                                                 0.0701      0.481      0.146      0.884      -0.876       1.016
# prob_Asian prob_Black                                                                                        0.0287      0.290      0.099      0.921      -0.542       0.599
# prob_Asian prob_Hispanic                                                                                     0.0455      0.412      0.110      0.912      -0.765       0.855
# prob_Asian prob_White                                                                                       -0.0290      0.330     -0.088      0.930      -0.677       0.619
# prob_Asian Metric Score - Weighted Regents Pass Rate, Science                                               -0.1814      0.147     -1.233      0.218      -0.471       0.108
# prob_Asian Metric Score - Weighted Regents Pass Rate, US History                                             0.0912      0.160      0.569      0.570      -0.224       0.406
# prob_Asian Metric Score - Four-year College Readiness Index                                                 -0.0160      0.142     -0.112      0.911      -0.296       0.264
# prob_Black^2                                                                                             -1.566e-05      1.068  -1.47e-05      1.000      -2.101       2.101
# prob_Black prob_Hispanic                                                                                     0.0373      0.651      0.057      0.954      -1.243       1.317
# prob_Black prob_White                                                                                       -0.0439      0.202     -0.217      0.828      -0.441       0.354
# prob_Black Metric Score - Weighted Regents Pass Rate, Science                                               -0.1994      0.205     -0.973      0.331      -0.602       0.203
# prob_Black Metric Score - Weighted Regents Pass Rate, US History                                             0.1513      0.222      0.682      0.496      -0.285       0.588
# prob_Black Metric Score - Four-year College Readiness Index                                                 -0.0859      0.182     -0.473      0.637      -0.443       0.271
# prob_Hispanic^2                                                                                              0.1969      1.143      0.172      0.863      -2.050       2.444
# prob_Hispanic prob_White                                                                                    -0.0331      0.316     -0.105      0.916      -0.654       0.587
# prob_Hispanic Metric Score - Weighted Regents Pass Rate, Science                                            -0.2893      0.246     -1.178      0.240      -0.772       0.194
# prob_Hispanic Metric Score - Weighted Regents Pass Rate, US History                                          0.2113      0.277      0.762      0.446      -0.334       0.757
# prob_Hispanic Metric Score - Four-year College Readiness Index                                              -0.0512      0.209     -0.246      0.806      -0.461       0.359
# prob_White^2                                                                                                -0.1354      0.330     -0.411      0.681      -0.784       0.513
# prob_White Metric Score - Weighted Regents Pass Rate, Science                                               -0.1161      0.110     -1.058      0.291      -0.332       0.100
# prob_White Metric Score - Weighted Regents Pass Rate, US History                                             0.0641      0.133      0.483      0.629      -0.197       0.325
# prob_White Metric Score - Four-year College Readiness Index                                                 -0.0253      0.117     -0.217      0.828      -0.255       0.205
# Metric Score - Weighted Regents Pass Rate, Science^2                                                        -0.0053      0.032     -0.164      0.870      -0.069       0.058
# Metric Score - Weighted Regents Pass Rate, Science Metric Score - Weighted Regents Pass Rate, US History    -0.0038      0.034     -0.110      0.913      -0.071       0.064
# Metric Score - Weighted Regents Pass Rate, Science Metric Score - Four-year College Readiness Index          0.0116      0.031      0.379      0.705      -0.049       0.072
# Metric Score - Weighted Regents Pass Rate, US History^2                                                      0.0488      0.030      1.609      0.108      -0.011       0.109
# Metric Score - Weighted Regents Pass Rate, US History Metric Score - Four-year College Readiness Index      -0.0092      0.030     -0.301      0.763      -0.069       0.051
# Metric Score - Four-year College Readiness Index^2                                                           0.0211      0.020      1.051      0.294      -0.018       0.061
# ==============================================================================
# Omnibus:                       32.875   Durbin-Watson:                   1.846
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.876
# Skew:                          -0.413   Prob(JB):                     9.08e-17
# Kurtosis:                       4.881   Cond. No.                     1.26e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.29e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
